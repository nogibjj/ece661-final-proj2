# %%
import mido
import numpy as np
from mido import Message, MidiFile, MidiTrack
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import pandas as pd

# %%
mid = MidiFile("midis/Q1__8v0MFBZoco_0.mid")

# %%
mid
# Out:
# MidiFile(type=1, ticks_per_beat=384, tracks=[
#   MidiTrack([
#     MetaMessage('set_tempo', tempo=500000, time=0),
#     MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0),
#     MetaMessage('end_of_track', time=1)]),
#   MidiTrack([
#     Message('note_on', channel=0, note=52, velocity=89, time=305),
#     Message('note_on', channel=0, note=64, velocity=90, time=2),
#     Message('note_on', channel=0, note=52, velocity=0, time=63),
#     Message('note_on', channel=0, note=64, velocity=0, time=2),
#     Message('note_on', channel=0, note=58, velocity=91, time=118),
#     Message('note_on', channel=0, note=70, velocity=83, time=2),
#     Message('note_on', channel=0, note=58, velocity=0, time=69),
#     Message('note_on', channel=0, note=70, velocity=0, time=25),
#     Message('note_on', channel=0, note=59, velocity=86, time=2),
#     Message('note_on', channel=0, note=71, velocity=78, time=0),
#     Message('note_on', channel=0, note=62, velocity=88, time=99),
#     Message('note_on', channel=0, note=59, velocity=0, time=0),
#     Message('note_on', channel=0, note=74, velocity=80, time=2),
#     Message('note_on', channel=0, note=71, velocity=0, time=7),
#     Message('note_on', channel=0, note=78, velocity=86, time=98),
#     Message('note_on', channel=0, note=66, velocity=86, time=1),
#     Message('note_on', channel=0, note=62, velocity=0, time=19),
#     Message('note_on', channel=0, note=74, velocity=0, time=17),
#     Message('note_on', channel=0, note=66, velocity=0, time=9),
#     Message('note_on', channel=0, note=78, velocity=0, time=4),
#     Message('note_on', channel=0, note=64, velocity=92, time=153),
#     Message('note_on', channel=0, note=76, velocity=94, time=0),
#     Message('note_on', channel=0, note=76, velocity=0, time=50),
#     Message('note_on', channel=0, note=64, velocity=0, time=2),
#     Message('note_on', channel=0, note=62, velocity=89, time=146),
#     Message('note_on', channel=0, note=74, velocity=88, time=0),
#     Message('note_on', channel=0, note=74, velocity=0, time=42),
#     Message('note_on', channel=0, note=62, velocity=0, time=1),
#     Message('note_on', channel=0, note=70, velocity=94, time=150),
#     Message('note_on', channel=0, note=58, velocity=94, time=1),
#     Message('control_change', channel=0, control=64, value=127, time=39),
#     Message('control_change', channel=0, control=64, value=0, time=138),
#     Message('note_on', channel=0, note=58, velocity=0, time=4),
#     Message('note_on', channel=0, note=71, velocity=83, time=1),
#     Message('note_on', channel=0, note=59, velocity=83, time=0),
#     Message('note_on', channel=0, note=70, velocity=0, time=7),
#     Message('note_on', channel=0, note=62, velocity=93, time=106),
#     Message('note_on', channel=0, note=74, velocity=89, time=0),
#     Message('note_on', channel=0, note=71, velocity=0, time=11),
#     Message('note_on', channel=0, note=59, velocity=0, time=3),
#     Message('note_on', channel=0, note=62, velocity=0, time=26),
#     Message('note_on', channel=0, note=74, velocity=0, time=65),
#     Message('note_on', channel=0, note=28, velocity=101, time=91),
#     Message('note_on', channel=0, note=28, velocity=0, time=101),
#     Message('note_on', channel=0, note=28, velocity=98, time=97),
#     Message('note_on', channel=0, note=28, velocity=0, time=118),
#     Message('note_on', channel=0, note=40, velocity=82, time=73),
#     Message('note_on', channel=0, note=55, velocity=76, time=1),
#     Message('note_on', channel=0, note=58, velocity=84, time=0),
#     Message('note_on', channel=0, note=55, velocity=0, time=93),
#     Message('note_on', channel=0, note=58, velocity=0, time=6),
#     Message('note_on', channel=0, note=56, velocity=83, time=0),
#     Message('note_on', channel=0, note=59, velocity=71, time=2),
#     Message('note_on', channel=0, note=33, velocity=83, time=202),
#     Message('note_on', channel=0, note=40, velocity=0, time=9),
#     Message('note_on', channel=0, note=56, velocity=0, time=48),
#     Message('note_on', channel=0, note=59, velocity=0, time=27),
#     Message('note_on', channel=0, note=33, velocity=0, time=119),
#     Message('note_on', channel=0, note=60, velocity=83, time=115),
#     Message('note_on', channel=0, note=63, velocity=80, time=0),
#     Message('note_on', channel=0, note=33, velocity=71, time=0),
#     Message('note_on', channel=0, note=64, velocity=73, time=94),
#     Message('note_on', channel=0, note=61, velocity=83, time=1),
#     Message('note_on', channel=0, note=63, velocity=0, time=5),
#     Message('note_on', channel=0, note=60, velocity=0, time=7),
#     Message('note_on', channel=0, note=61, velocity=0, time=75),
#     Message('note_on', channel=0, note=45, velocity=89, time=0),
#     Message('note_on', channel=0, note=33, velocity=0, time=45),
#     Message('note_on', channel=0, note=60, velocity=78, time=64),
#     Message('note_on', channel=0, note=63, velocity=73, time=0),
#     Message('note_on', channel=0, note=64, velocity=0, time=35),
#     Message('note_on', channel=0, note=64, velocity=80, time=66),
#     Message('note_on', channel=0, note=61, velocity=88, time=1),
#     Message('note_on', channel=0, note=63, velocity=0, time=3),
#     Message('note_on', channel=0, note=33, velocity=79, time=3),
#     Message('note_on', channel=0, note=60, velocity=0, time=35),
#     Message('note_on', channel=0, note=45, velocity=0, time=2),
#     Message('note_on', channel=0, note=33, velocity=0, time=36),
#     Message('note_on', channel=0, note=61, velocity=0, time=39),
#     Message('note_on', channel=0, note=64, velocity=0, time=30),
#     Message('note_on', channel=0, note=28, velocity=101, time=48),
#     Message('note_on', channel=0, note=28, velocity=0, time=114),
#     Message('note_on', channel=0, note=28, velocity=96, time=92),
#     Message('note_on', channel=0, note=67, velocity=79, time=188),
#     Message('note_on', channel=0, note=40, velocity=80, time=1),
#     Message('note_on', channel=0, note=70, velocity=91, time=3),
#     Message('note_on', channel=0, note=28, velocity=0, time=23),
#     Message('note_on', channel=0, note=70, velocity=0, time=65),
#     Message('note_on', channel=0, note=68, velocity=81, time=6),
#     Message('note_on', channel=0, note=71, velocity=73, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=21),
#     Message('note_on', channel=0, note=33, velocity=87, time=173),
#     Message('note_on', channel=0, note=40, velocity=0, time=19),
#     Message('note_on', channel=0, note=68, velocity=0, time=31),
#     Message('note_on', channel=0, note=71, velocity=0, time=138),
#     Message('note_on', channel=0, note=33, velocity=0, time=23),
#     Message('note_on', channel=0, note=33, velocity=84, time=110),
#     Message('note_on', channel=0, note=75, velocity=87, time=0),
#     Message('note_on', channel=0, note=72, velocity=80, time=2),
#     Message('note_on', channel=0, note=73, velocity=78, time=85),
#     Message('note_on', channel=0, note=76, velocity=75, time=4),
#     Message('note_on', channel=0, note=75, velocity=0, time=13),
#     Message('note_on', channel=0, note=72, velocity=0, time=9),
#     Message('note_on', channel=0, note=33, velocity=0, time=48),
#     Message('note_on', channel=0, note=73, velocity=0, time=6),
#     Message('note_on', channel=0, note=76, velocity=0, time=5),
#     Message('note_on', channel=0, note=45, velocity=90, time=12),
#     Message('note_on', channel=0, note=72, velocity=75, time=104),
#     Message('note_on', channel=0, note=75, velocity=78, time=2),
#     Message('note_on', channel=0, note=33, velocity=83, time=96),
#     Message('note_on', channel=0, note=73, velocity=85, time=2),
#     Message('note_on', channel=0, note=76, velocity=88, time=1),
#     Message('note_on', channel=0, note=75, velocity=0, time=16),
#     Message('note_on', channel=0, note=45, velocity=0, time=23),
#     Message('note_on', channel=0, note=72, velocity=0, time=0),
#     Message('note_on', channel=0, note=33, velocity=0, time=5),
#     Message('note_on', channel=0, note=73, velocity=0, time=5),
#     Message('note_on', channel=0, note=28, velocity=101, time=141),
#     Message('note_on', channel=0, note=28, velocity=0, time=148),
#     Message('note_on', channel=0, note=76, velocity=0, time=8),
#     Message('note_on', channel=0, note=28, velocity=96, time=54),
#     Message('note_on', channel=0, note=28, velocity=0, time=153),
#     Message('note_on', channel=0, note=40, velocity=86, time=43),
#     Message('note_on', channel=0, note=82, velocity=95, time=0),
#     Message('note_on', channel=0, note=79, velocity=93, time=0),
#     Message('note_on', channel=0, note=80, velocity=88, time=99),
#     Message('note_on', channel=0, note=83, velocity=70, time=1),
#     Message('note_on', channel=0, note=40, velocity=0, time=177),
#     Message('note_on', channel=0, note=33, velocity=88, time=15),
#     Message('note_on', channel=0, note=80, velocity=0, time=4),
#     Message('note_on', channel=0, note=82, velocity=0, time=22),
#     Message('note_on', channel=0, note=83, velocity=0, time=92),
#     Message('note_on', channel=0, note=33, velocity=0, time=67),
#     Message('note_on', channel=0, note=79, velocity=0, time=10),
#     Message('note_on', channel=0, note=87, velocity=94, time=119),
#     Message('note_on', channel=0, note=33, velocity=88, time=1),
#     Message('note_on', channel=0, note=84, velocity=79, time=0),
#     Message('note_on', channel=0, note=88, velocity=84, time=85),
#     Message('note_on', channel=0, note=85, velocity=83, time=1),
#     Message('note_on', channel=0, note=33, velocity=0, time=94),
#     Message('note_on', channel=0, note=45, velocity=96, time=18),
#     Message('note_on', channel=0, note=84, velocity=0, time=5),
#     Message('note_on', channel=0, note=87, velocity=0, time=84),
#     Message('note_on', channel=0, note=84, velocity=78, time=7),
#     Message('note_on', channel=0, note=87, velocity=86, time=1),
#     Message('note_on', channel=0, note=85, velocity=0, time=84),
#     Message('note_on', channel=0, note=88, velocity=0, time=0),
#     Message('note_on', channel=0, note=87, velocity=0, time=2),
#     Message('note_on', channel=0, note=33, velocity=83, time=2),
#     Message('note_on', channel=0, note=88, velocity=80, time=2),
#     Message('note_on', channel=0, note=85, velocity=81, time=2),
#     Message('note_on', channel=0, note=45, velocity=0, time=36),
#     Message('note_on', channel=0, note=84, velocity=0, time=2),
#     Message('note_on', channel=0, note=33, velocity=0, time=47),
#     Message('note_on', channel=0, note=85, velocity=0, time=7),
#     Message('note_on', channel=0, note=88, velocity=0, time=62),
#     Message('note_on', channel=0, note=40, velocity=95, time=41),
#     Message('note_on', channel=0, note=28, velocity=101, time=1),
#     Message('note_on', channel=0, note=100, velocity=104, time=1),
#     Message('control_change', channel=0, control=64, value=127, time=49),
#     Message('note_on', channel=0, note=98, velocity=103, time=45),
#     Message('note_on', channel=0, note=95, velocity=92, time=110),
#     Message('note_on', channel=0, note=93, velocity=88, time=95),
#     Message('note_on', channel=0, note=91, velocity=85, time=100),
#     Message('note_on', channel=0, note=100, velocity=0, time=3),
#     Message('note_on', channel=0, note=88, velocity=78, time=98),
#     Message('note_on', channel=0, note=98, velocity=0, time=2),
#     Message('note_on', channel=0, note=86, velocity=86, time=100),
#     Message('note_on', channel=0, note=83, velocity=84, time=107),
#     Message('note_on', channel=0, note=88, velocity=0, time=85),
#     Message('note_on', channel=0, note=88, velocity=96, time=9),
#     Message('control_change', channel=0, control=64, value=0, time=29),
#     Message('note_on', channel=0, note=86, velocity=0, time=62),
#     Message('note_on', channel=0, note=93, velocity=0, time=7),
#     Message('note_on', channel=0, note=86, velocity=83, time=3),
#     Message('note_on', channel=0, note=91, velocity=0, time=13),
#     Message('control_change', channel=0, control=64, value=127, time=7),
#     Message('note_on', channel=0, note=83, velocity=0, time=69),
#     Message('note_on', channel=0, note=83, velocity=81, time=10),
#     Message('note_on', channel=0, note=81, velocity=75, time=101),
#     Message('note_on', channel=0, note=79, velocity=76, time=96),
#     Message('control_change', channel=0, control=64, value=0, time=70),
#     Message('note_on', channel=0, note=76, velocity=73, time=35),
#     Message('note_on', channel=0, note=74, velocity=59, time=98),
#     Message('note_on', channel=0, note=71, velocity=76, time=92),
#     Message('note_on', channel=0, note=95, velocity=0, time=40),
#     Message('note_on', channel=0, note=28, velocity=0, time=0),
#     Message('note_on', channel=0, note=74, velocity=0, time=1),
#     Message('note_on', channel=0, note=86, velocity=0, time=1),
#     Message('note_on', channel=0, note=88, velocity=0, time=0),
#     Message('note_on', channel=0, note=83, velocity=0, time=1),
#     Message('note_on', channel=0, note=40, velocity=0, time=1),
#     Message('note_on', channel=0, note=76, velocity=0, time=1),
#     Message('note_on', channel=0, note=81, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=0, time=1),
#     Message('note_on', channel=0, note=71, velocity=0, time=40),
#     Message('note_on', channel=0, note=52, velocity=64, time=14),
#     Message('note_on', channel=0, note=74, velocity=76, time=1),
#     Message('note_on', channel=0, note=74, velocity=0, time=90),
#     Message('note_on', channel=0, note=76, velocity=70, time=4),
#     Message('note_on', channel=0, note=52, velocity=0, time=5),
#     Message('note_on', channel=0, note=76, velocity=0, time=90),
#     Message('note_on', channel=0, note=76, velocity=83, time=5),
#     Message('note_on', channel=0, note=52, velocity=57, time=4),
#     Message('note_on', channel=0, note=76, velocity=0, time=183),
#     Message('note_on', channel=0, note=59, velocity=61, time=7),
#     Message('note_on', channel=0, note=62, velocity=65, time=2),
#     Message('note_on', channel=0, note=76, velocity=87, time=0),
#     Message('note_on', channel=0, note=56, velocity=57, time=7),
#     Message('note_on', channel=0, note=74, velocity=69, time=188),
#     Message('note_on', channel=0, note=52, velocity=0, time=8),
#     Message('note_on', channel=0, note=56, velocity=0, time=3),
#     Message('note_on', channel=0, note=59, velocity=0, time=3),
#     Message('note_on', channel=0, note=62, velocity=0, time=0),
#     Message('note_on', channel=0, note=76, velocity=0, time=0),
#     Message('note_on', channel=0, note=45, velocity=67, time=87),
#     Message('note_on', channel=0, note=79, velocity=95, time=4),
#     Message('note_on', channel=0, note=74, velocity=0, time=121),
#     Message('note_on', channel=0, note=79, velocity=0, time=61),
#     Message('note_on', channel=0, note=79, velocity=84, time=7),
#     Message('note_on', channel=0, note=45, velocity=0, time=86),
#     Message('note_on', channel=0, note=52, velocity=65, time=20),
#     Message('note_on', channel=0, note=69, velocity=71, time=97),
#     Message('note_on', channel=0, note=69, velocity=0, time=74),
#     Message('note_on', channel=0, note=71, velocity=77, time=20),
#     Message('note_on', channel=0, note=61, velocity=63, time=0),
#     Message('note_on', channel=0, note=57, velocity=60, time=4),
#     Message('note_on', channel=0, note=55, velocity=58, time=5),
#     Message('control_change', channel=0, control=64, value=127, time=2),
#     Message('note_on', channel=0, note=79, velocity=0, time=38),
#     Message('note_on', channel=0, note=74, velocity=82, time=38),
#     Message('note_on', channel=0, note=52, velocity=0, time=101),
#     Message('note_on', channel=0, note=76, velocity=85, time=9),
#     Message('note_on', channel=0, note=52, velocity=68, time=0),
#     Message('note_on', channel=0, note=57, velocity=0, time=104),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=74, velocity=0, time=1),
#     Message('control_change', channel=0, control=64, value=0, time=0),
#     Message('note_on', channel=0, note=61, velocity=0, time=2),
#     Message('note_on', channel=0, note=55, velocity=0, time=0),
#     Message('note_on', channel=0, note=52, velocity=0, time=1),
#     Message('note_on', channel=0, note=76, velocity=0, time=1),
#     Message('note_on', channel=0, note=40, velocity=72, time=84),
#     Message('note_on', channel=0, note=76, velocity=84, time=1),
#     Message('control_change', channel=0, control=64, value=127, time=142),
#     Message('note_on', channel=0, note=74, velocity=72, time=44),
#     Message('note_on', channel=0, note=76, velocity=0, time=48),
#     Message('control_change', channel=0, control=64, value=0, time=4),
#     Message('note_on', channel=0, note=76, velocity=69, time=8),
#     Message('note_on', channel=0, note=74, velocity=0, time=0),
#     Message('note_on', channel=0, note=40, velocity=0, time=4),
#     Message('note_on', channel=0, note=74, velocity=70, time=62),
#     Message('note_on', channel=0, note=56, velocity=71, time=63),
#     Message('note_on', channel=0, note=59, velocity=74, time=0),
#     Message('note_on', channel=0, note=71, velocity=91, time=0),
#     Message('note_on', channel=0, note=52, velocity=66, time=1),
#     Message('note_on', channel=0, note=76, velocity=0, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=123),
#     Message('note_on', channel=0, note=52, velocity=0, time=26),
#     Message('note_on', channel=0, note=56, velocity=0, time=20),
#     Message('note_on', channel=0, note=59, velocity=0, time=15),
#     Message('note_on', channel=0, note=45, velocity=73, time=94),
#     Message('control_change', channel=0, control=64, value=127, time=37),
#     Message('control_change', channel=0, control=64, value=0, time=200),
#     Message('note_on', channel=0, note=45, velocity=0, time=3),
#     Message('note_on', channel=0, note=71, velocity=0, time=1),
#     Message('note_on', channel=0, note=52, velocity=65, time=65),
#     Message('note_on', channel=0, note=52, velocity=0, time=87),
#     Message('note_on', channel=0, note=61, velocity=67, time=111),
#     Message('note_on', channel=0, note=57, velocity=68, time=1),
#     Message('note_on', channel=0, note=55, velocity=61, time=4),
#     Message('control_change', channel=0, control=64, value=127, time=81),
#     Message('note_on', channel=0, note=52, velocity=67, time=98),
#     Message('note_on', channel=0, note=55, velocity=0, time=114),
#     Message('note_on', channel=0, note=61, velocity=0, time=0),
#     Message('note_on', channel=0, note=52, velocity=0, time=1),
#     Message('control_change', channel=0, control=64, value=0, time=3),
#     Message('note_on', channel=0, note=57, velocity=0, time=1),
#     Message('note_on', channel=0, note=74, velocity=96, time=91),
#     Message('note_on', channel=0, note=40, velocity=75, time=1),
#     Message('note_on', channel=0, note=76, velocity=84, time=190),
#     Message('note_on', channel=0, note=40, velocity=0, time=38),
#     Message('note_on', channel=0, note=74, velocity=0, time=8),
#     Message('note_on', channel=0, note=76, velocity=0, time=2),
#     Message('note_on', channel=0, note=76, velocity=96, time=148),
#     Message('note_on', channel=0, note=59, velocity=65, time=0),
#     Message('note_on', channel=0, note=56, velocity=67, time=6),
#     Message('note_on', channel=0, note=52, velocity=58, time=0),
#     Message('note_on', channel=0, note=59, velocity=0, time=31),
#     Message('note_on', channel=0, note=56, velocity=0, time=28),
#     Message('note_on', channel=0, note=74, velocity=71, time=112),
#     Message('note_on', channel=0, note=76, velocity=0, time=35),
#     Message('note_on', channel=0, note=74, velocity=0, time=3),
#     Message('note_on', channel=0, note=52, velocity=0, time=4),
#     Message('note_on', channel=0, note=79, velocity=100, time=74),
#     Message('note_on', channel=0, note=45, velocity=70, time=1),
#     Message('note_on', channel=0, note=79, velocity=0, time=63),
#     Message('control_change', channel=0, control=64, value=127, time=0),
#     Message('note_on', channel=0, note=79, velocity=96, time=125),
#     Message('control_change', channel=0, control=64, value=0, time=63),
#     Message('note_on', channel=0, note=45, velocity=0, time=0),
#     Message('note_on', channel=0, note=52, velocity=70, time=45),
#     Message('note_on', channel=0, note=71, velocity=71, time=84),
#     Message('control_change', channel=0, control=64, value=127, time=29),
#     Message('note_on', channel=0, note=61, velocity=74, time=60),
#     Message('note_on', channel=0, note=57, velocity=71, time=2),
#     Message('note_on', channel=0, note=55, velocity=70, time=2),
#     Message('note_on', channel=0, note=76, velocity=81, time=86),
#     Message('note_on', channel=0, note=52, velocity=0, time=80),
#     Message('note_on', channel=0, note=52, velocity=72, time=5),
#     Message('note_on', channel=0, note=79, velocity=0, time=3),
#     Message('note_on', channel=0, note=79, velocity=90, time=3),
#     Message('note_on', channel=0, note=88, velocity=97, time=102),
#     Message('control_change', channel=0, control=64, value=0, time=3),
#     Message('note_on', channel=0, note=57, velocity=0, time=2),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=52, velocity=0, time=1),
#     Message('note_on', channel=0, note=61, velocity=0, time=0),
#     Message('note_on', channel=0, note=55, velocity=0, time=0),
#     Message('note_on', channel=0, note=76, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=0, time=2),
#     Message('note_on', channel=0, note=40, velocity=82, time=99),
#     Message('note_on', channel=0, note=86, velocity=89, time=185),
#     Message('note_on', channel=0, note=88, velocity=0, time=36),
#     Message('note_on', channel=0, note=40, velocity=0, time=12),
#     Message('note_on', channel=0, note=83, velocity=90, time=150),
#     Message('note_on', channel=0, note=59, velocity=73, time=0),
#     Message('note_on', channel=0, note=52, velocity=66, time=1),
#     Message('note_on', channel=0, note=56, velocity=73, time=2),
#     Message('control_change', channel=0, control=64, value=127, time=108),
#     Message('note_on', channel=0, note=52, velocity=0, time=101),
#     Message('control_change', channel=0, control=64, value=0, time=0),
#     Message('note_on', channel=0, note=56, velocity=0, time=2),
#     Message('note_on', channel=0, note=59, velocity=0, time=4),
#     Message('note_on', channel=0, note=86, velocity=0, time=24),
#     Message('note_on', channel=0, note=45, velocity=75, time=43),
#     Message('control_change', channel=0, control=64, value=127, time=49),
#     Message('note_on', channel=0, note=83, velocity=0, time=238),
#     Message('control_change', channel=0, control=64, value=0, time=11),
#     Message('note_on', channel=0, note=45, velocity=0, time=1),
#     Message('note_on', channel=0, note=52, velocity=65, time=7),
#     Message('note_on', channel=0, note=52, velocity=0, time=99),
#     Message('note_on', channel=0, note=61, velocity=60, time=101),
#     Message('note_on', channel=0, note=57, velocity=59, time=4),
#     Message('note_on', channel=0, note=55, velocity=56, time=2),
#     Message('control_change', channel=0, control=64, value=127, time=51),
#     Message('note_on', channel=0, note=52, velocity=67, time=123),
#     Message('note_on', channel=0, note=64, velocity=74, time=88),
#     Message('note_on', channel=0, note=61, velocity=0, time=74),
#     Message('note_on', channel=0, note=55, velocity=0, time=2),
#     Message('note_on', channel=0, note=57, velocity=0, time=1),
#     Message('note_on', channel=0, note=52, velocity=0, time=0),
#     Message('note_on', channel=0, note=64, velocity=0, time=3),
#     Message('control_change', channel=0, control=64, value=0, time=3),
#     Message('note_on', channel=0, note=68, velocity=74, time=25),
#     Message('note_on', channel=0, note=40, velocity=78, time=1),
#     Message('note_on', channel=0, note=76, velocity=59, time=2),
#     Message('note_on', channel=0, note=71, velocity=67, time=1),
#     Message('note_on', channel=0, note=68, velocity=0, time=26),
#     Message('note_on', channel=0, note=40, velocity=0, time=20),
#     Message('note_on', channel=0, note=76, velocity=0, time=0),
#     Message('control_change', channel=0, control=64, value=127, time=31),
#     Message('note_on', channel=0, note=71, velocity=0, time=7),
#     Message('note_on', channel=0, note=68, velocity=79, time=4),
#     Message('note_on', channel=0, note=71, velocity=81, time=0),
#     Message('note_on', channel=0, note=76, velocity=75, time=5),
#     Message('note_on', channel=0, note=64, velocity=75, time=2),
#     Message('note_on', channel=0, note=68, velocity=0, time=89),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=76, velocity=0, time=0),
#     Message('note_on', channel=0, note=64, velocity=0, time=8),
#     Message('note_on', channel=0, note=71, velocity=81, time=3),
#     Message('note_on', channel=0, note=68, velocity=86, time=0),
#     Message('note_on', channel=0, note=76, velocity=82, time=0),
#     Message('note_on', channel=0, note=64, velocity=77, time=1),
#     Message('note_on', channel=0, note=64, velocity=0, time=180),
#     Message('note_on', channel=0, note=68, velocity=0, time=0),
#     Message('note_on', channel=0, note=64, velocity=78, time=7),
#     Message('note_on', channel=0, note=71, velocity=0, time=1),
#     Message('note_on', channel=0, note=76, velocity=0, time=0),
#     Message('note_on', channel=0, note=68, velocity=86, time=2),
#     Message('note_on', channel=0, note=56, velocity=87, time=0),
#     Message('note_on', channel=0, note=59, velocity=81, time=1),
#     Message('note_on', channel=0, note=76, velocity=81, time=1),
#     Message('note_on', channel=0, note=71, velocity=75, time=0),
#     Message('note_on', channel=0, note=67, velocity=66, time=185),
#     Message('control_change', channel=0, control=64, value=0, time=31),
#     Message('note_on', channel=0, note=64, velocity=0, time=6),
#     Message('note_on', channel=0, note=68, velocity=0, time=0),
#     Message('note_on', channel=0, note=56, velocity=0, time=0),
#     Message('note_on', channel=0, note=59, velocity=0, time=1),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=76, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=86, time=69),
#     Message('note_on', channel=0, note=71, velocity=72, time=0),
#     Message('note_on', channel=0, note=43, velocity=81, time=0),
#     Message('note_on', channel=0, note=67, velocity=80, time=0),
#     Message('note_on', channel=0, note=74, velocity=70, time=3),
#     Message('control_change', channel=0, control=64, value=127, time=70),
#     Message('note_on', channel=0, note=67, velocity=0, time=123),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=74, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=88, time=6),
#     Message('note_on', channel=0, note=67, velocity=83, time=0),
#     Message('note_on', channel=0, note=71, velocity=78, time=1),
#     Message('note_on', channel=0, note=74, velocity=69, time=1),
#     Message('note_on', channel=0, note=50, velocity=76, time=97),
#     Message('note_on', channel=0, note=67, velocity=0, time=94),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=74, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=88, time=5),
#     Message('note_on', channel=0, note=79, velocity=88, time=0),
#     Message('note_on', channel=0, note=74, velocity=77, time=3),
#     Message('note_on', channel=0, note=71, velocity=83, time=0),
#     Message('note_on', channel=0, note=59, velocity=91, time=88),
#     Message('note_on', channel=0, note=55, velocity=81, time=0),
#     Message('note_on', channel=0, note=50, velocity=0, time=188),
#     Message('note_on', channel=0, note=50, velocity=78, time=7),
#     Message('note_on', channel=0, note=43, velocity=0, time=157),
#     Message('note_on', channel=0, note=67, velocity=0, time=1),
#     Message('note_on', channel=0, note=50, velocity=0, time=0),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=55, velocity=0, time=0),
#     Message('note_on', channel=0, note=74, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=0, time=0),
#     Message('note_on', channel=0, note=59, velocity=0, time=0),
#     Message('control_change', channel=0, control=64, value=0, time=0),
#     Message('note_on', channel=0, note=45, velocity=77, time=61),
#     Message('note_on', channel=0, note=76, velocity=75, time=6),
#     Message('note_on', channel=0, note=73, velocity=69, time=2),
#     Message('note_on', channel=0, note=69, velocity=73, time=0),
#     Message('note_on', channel=0, note=64, velocity=77, time=0),
#     Message('note_on', channel=0, note=45, velocity=0, time=26),
#     Message('control_change', channel=0, control=64, value=127, time=9),
#     Message('note_on', channel=0, note=64, velocity=0, time=46),
#     Message('note_on', channel=0, note=69, velocity=0, time=0),
#     Message('note_on', channel=0, note=73, velocity=0, time=0),
#     Message('note_on', channel=0, note=76, velocity=0, time=0),
#     Message('note_on', channel=0, note=73, velocity=85, time=8),
#     Message('note_on', channel=0, note=76, velocity=76, time=2),
#     Message('note_on', channel=0, note=64, velocity=77, time=0),
#     Message('note_on', channel=0, note=69, velocity=75, time=1),
#     Message('note_on', channel=0, note=76, velocity=0, time=81),
#     Message('note_on', channel=0, note=64, velocity=0, time=8),
#     Message('note_on', channel=0, note=69, velocity=0, time=0),
#     Message('note_on', channel=0, note=73, velocity=0, time=0),
#     Message('note_on', channel=0, note=76, velocity=89, time=4),
#     Message('note_on', channel=0, note=69, velocity=73, time=0),
#     Message('note_on', channel=0, note=73, velocity=79, time=1),
#     Message('note_on', channel=0, note=64, velocity=80, time=0),
#     Message('note_on', channel=0, note=64, velocity=0, time=187),
#     Message('note_on', channel=0, note=69, velocity=0, time=0),
#     Message('note_on', channel=0, note=73, velocity=0, time=0),
#     Message('note_on', channel=0, note=76, velocity=0, time=0),
#     Message('note_on', channel=0, note=61, velocity=81, time=5),
#     Message('note_on', channel=0, note=76, velocity=90, time=1),
#     Message('note_on', channel=0, note=64, velocity=85, time=1),
#     Message('note_on', channel=0, note=69, velocity=81, time=2),
#     Message('note_on', channel=0, note=57, velocity=80, time=1),
#     Message('note_on', channel=0, note=73, velocity=81, time=1),
#     Message('control_change', channel=0, control=64, value=0, time=58),
#     Message('control_change', channel=0, control=64, value=127, time=85),
#     Message('note_on', channel=0, note=67, velocity=72, time=42),
#     Message('note_on', channel=0, note=64, velocity=0, time=67),
#     Message('note_on', channel=0, note=73, velocity=0, time=0),
#     Message('note_on', channel=0, note=61, velocity=0, time=0),
#     Message('note_on', channel=0, note=69, velocity=0, time=0),
#     Message('note_on', channel=0, note=76, velocity=0, time=0),
#     Message('note_on', channel=0, note=57, velocity=0, time=1),
#     Message('control_change', channel=0, control=64, value=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=28),
#     Message('note_on', channel=0, note=79, velocity=83, time=4),
#     Message('note_on', channel=0, note=67, velocity=78, time=1),
#     Message('note_on', channel=0, note=50, velocity=82, time=1),
#     Message('note_on', channel=0, note=72, velocity=75, time=2),
#     Message('control_change', channel=0, control=64, value=127, time=53),
#     Message('note_on', channel=0, note=67, velocity=0, time=139),
#     Message('note_on', channel=0, note=72, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=84, time=9),
#     Message('note_on', channel=0, note=79, velocity=85, time=1),
#     Message('note_on', channel=0, note=72, velocity=80, time=1),
#     Message('note_on', channel=0, note=50, velocity=0, time=88),
#     Message('note_on', channel=0, note=50, velocity=78, time=9),
#     Message('note_on', channel=0, note=67, velocity=0, time=91),
#     Message('note_on', channel=0, note=72, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=90, time=4),
#     Message('note_on', channel=0, note=67, velocity=85, time=1),
#     Message('note_on', channel=0, note=72, velocity=85, time=2),
#     Message('note_on', channel=0, note=74, velocity=82, time=1),
#     Message('note_on', channel=0, note=60, velocity=76, time=97),
#     Message('note_on', channel=0, note=57, velocity=73, time=0),
#     Message('note_on', channel=0, note=54, velocity=71, time=4),
#     Message('note_on', channel=0, note=50, velocity=0, time=175),
#     Message('note_on', channel=0, note=79, velocity=0, time=0),
#     Message('note_on', channel=0, note=50, velocity=71, time=5),
#     Message('note_on', channel=0, note=79, velocity=95, time=1),
#     Message('note_on', channel=0, note=76, velocity=74, time=109),
#     Message('note_on', channel=0, note=67, velocity=0, time=26),
#     Message('note_on', channel=0, note=79, velocity=0, time=1),
#     Message('note_on', channel=0, note=74, velocity=0, time=0),
#     Message('note_on', channel=0, note=72, velocity=0, time=1),
#     Message('note_on', channel=0, note=57, velocity=0, time=1),
#     Message('note_on', channel=0, note=54, velocity=0, time=0),
#     Message('note_on', channel=0, note=50, velocity=0, time=1),
#     Message('note_on', channel=0, note=60, velocity=0, time=1),
#     Message('control_change', channel=0, control=64, value=0, time=1),
#     Message('note_on', channel=0, note=52, velocity=86, time=70),
#     Message('note_on', channel=0, note=79, velocity=92, time=0),
#     Message('note_on', channel=0, note=76, velocity=0, time=45),
#     Message('note_on', channel=0, note=76, velocity=80, time=56),
#     Message('note_on', channel=0, note=79, velocity=0, time=25),
#     Message('note_on', channel=0, note=52, velocity=0, time=1),
#     Message('note_on', channel=0, note=76, velocity=0, time=70),
#     Message('note_on', channel=0, note=79, velocity=83, time=10),
#     Message('note_on', channel=0, note=76, velocity=70, time=100),
#     Message('note_on', channel=0, note=79, velocity=0, time=91),
#     Message('note_on', channel=0, note=79, velocity=89, time=6),
#     Message('note_on', channel=0, note=64, velocity=71, time=0),
#     Message('note_on', channel=0, note=59, velocity=68, time=5),
#     Message('note_on', channel=0, note=56, velocity=64, time=2),
#     Message('note_on', channel=0, note=76, velocity=0, time=1),
#     Message('note_on', channel=0, note=76, velocity=82, time=93),
#     Message('note_on', channel=0, note=64, velocity=0, time=94),
#     Message('note_on', channel=0, note=59, velocity=0, time=22),
#     Message('note_on', channel=0, note=56, velocity=0, time=7),
#     Message('note_on', channel=0, note=76, velocity=0, time=54),
#     Message('note_on', channel=0, note=47, velocity=79, time=12),
#     Message('note_on', channel=0, note=71, velocity=81, time=5),
#     Message('note_on', channel=0, note=79, velocity=0, time=21),
#     Message('control_change', channel=0, control=64, value=127, time=16),
#     Message('note_on', channel=0, note=71, velocity=0, time=146),
#     Message('note_on', channel=0, note=71, velocity=72, time=11),
#     Message('control_change', channel=0, control=64, value=0, time=61),
#     Message('note_on', channel=0, note=47, velocity=0, time=1),
#     Message('note_on', channel=0, note=71, velocity=0, time=27),
#     Message('note_on', channel=0, note=54, velocity=71, time=6),
#     Message('note_on', channel=0, note=71, velocity=70, time=1),
#     Message('control_change', channel=0, control=64, value=127, time=31),
#     Message('note_on', channel=0, note=71, velocity=0, time=54),
#     Message('note_on', channel=0, note=71, velocity=78, time=5),
#     Message('note_on', channel=0, note=57, velocity=71, time=104),
#     Message('note_on', channel=0, note=63, velocity=70, time=1),
#     Message('note_on', channel=0, note=73, velocity=76, time=0),
#     Message('note_on', channel=0, note=76, velocity=72, time=101),
#     Message('note_on', channel=0, note=54, velocity=0, time=81),
#     Message('note_on', channel=0, note=54, velocity=73, time=7),
#     Message('note_on', channel=0, note=80, velocity=92, time=94),
#     Message('note_on', channel=0, note=73, velocity=0, time=41),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=63, velocity=0, time=1),
#     Message('note_on', channel=0, note=54, velocity=0, time=1),
#     Message('note_on', channel=0, note=76, velocity=0, time=0),
#     Message('note_on', channel=0, note=57, velocity=0, time=2),
#     Message('control_change', channel=0, control=64, value=0, time=1),
#     Message('note_on', channel=0, note=40, velocity=73, time=65),
#     Message('control_change', channel=0, control=64, value=127, time=33),
#     Message('note_on', channel=0, note=76, velocity=88, time=49),
#     Message('control_change', channel=0, control=64, value=0, time=236),
#     Message('note_on', channel=0, note=40, velocity=0, time=22),
#     Message('note_on', channel=0, note=56, velocity=65, time=43),
#     Message('note_on', channel=0, note=59, velocity=71, time=1),
#     Message('note_on', channel=0, note=52, velocity=63, time=1),
#     Message('control_change', channel=0, control=64, value=127, time=78),
#     Message('control_change', channel=0, control=64, value=0, time=143),
#     Message('note_on', channel=0, note=52, velocity=0, time=3),
#     Message('note_on', channel=0, note=59, velocity=0, time=0),
#     Message('note_on', channel=0, note=56, velocity=0, time=6),
#     Message('note_on', channel=0, note=45, velocity=83, time=56),
#     Message('control_change', channel=0, control=64, value=127, time=46),
#     Message('control_change', channel=0, control=64, value=0, time=257),
#     Message('note_on', channel=0, note=45, velocity=0, time=4),
#     Message('note_on', channel=0, note=52, velocity=74, time=7),
#     Message('note_on', channel=0, note=83, velocity=95, time=92),
#     Message('control_change', channel=0, control=64, value=127, time=8),
#     Message('note_on', channel=0, note=80, velocity=0, time=31),
#     Message('note_on', channel=0, note=61, velocity=73, time=54),
#     Message('note_on', channel=0, note=57, velocity=71, time=2),
#     Message('note_on', channel=0, note=55, velocity=68, time=1),
#     Message('note_on', channel=0, note=81, velocity=92, time=99),
#     Message('note_on', channel=0, note=52, velocity=0, time=82),
#     Message('note_on', channel=0, note=52, velocity=69, time=5),
#     Message('note_on', channel=0, note=79, velocity=85, time=100),
#     Message('control_change', channel=0, control=64, value=0, time=5),
#     Message('note_on', channel=0, note=61, velocity=0, time=2),
#     Message('note_on', channel=0, note=52, velocity=0, time=0),
#     Message('note_on', channel=0, note=55, velocity=0, time=2),
#     Message('note_on', channel=0, note=57, velocity=0, time=0),
#     Message('note_on', channel=0, note=83, velocity=0, time=2),
#     Message('note_on', channel=0, note=81, velocity=0, time=3),
#     Message('note_on', channel=0, note=80, velocity=91, time=2),
#     Message('note_on', channel=0, note=76, velocity=0, time=2),
#     Message('note_on', channel=0, note=40, velocity=83, time=84),
#     Message('control_change', channel=0, control=64, value=127, time=39),
#     Message('note_on', channel=0, note=76, velocity=76, time=78),
#     Message('note_on', channel=0, note=76, velocity=0, time=191),
#     Message('note_on', channel=0, note=76, velocity=92, time=5),
#     Message('control_change', channel=0, control=64, value=0, time=8),
#     Message('note_on', channel=0, note=40, velocity=0, time=5),
#     Message('note_on', channel=0, note=80, velocity=0, time=8),
#     Message('note_on', channel=0, note=79, velocity=0, time=5),
#     Message('note_on', channel=0, note=56, velocity=79, time=55),
#     Message('note_on', channel=0, note=59, velocity=82, time=1),
#     Message('note_on', channel=0, note=52, velocity=79, time=0),
#     Message('note_on', channel=0, note=52, velocity=0, time=236),
#     Message('note_on', channel=0, note=59, velocity=0, time=3),
#     Message('note_on', channel=0, note=56, velocity=0, time=12),
#     Message('note_on', channel=0, note=47, velocity=96, time=52),
#     Message('note_on', channel=0, note=35, velocity=85, time=3),
#     Message('control_change', channel=0, control=64, value=127, time=45),
#     Message('note_on', channel=0, note=58, velocity=94, time=251),
#     Message('note_on', channel=0, note=35, velocity=0, time=2),
#     Message('note_on', channel=0, note=35, velocity=77, time=5),
#     Message('note_on', channel=0, note=64, velocity=72, time=3),
#     Message('control_change', channel=0, control=64, value=0, time=13),
#     Message('note_on', channel=0, note=47, velocity=0, time=3),
#     Message('note_on', channel=0, note=59, velocity=77, time=5),
#     Message('note_on', channel=0, note=58, velocity=0, time=6),
#     Message('note_on', channel=0, note=76, velocity=0, time=42),
#     Message('note_on', channel=0, note=35, velocity=0, time=84),
#     Message('note_on', channel=0, note=57, velocity=95, time=35),
#     Message('note_on', channel=0, note=47, velocity=89, time=5),
#     Message('note_on', channel=0, note=59, velocity=0, time=6),
#     Message('control_change', channel=0, control=64, value=127, time=62),
#     Message('note_on', channel=0, note=55, velocity=90, time=23),
#     Message('note_on', channel=0, note=35, velocity=80, time=90),
#     Message('note_on', channel=0, note=35, velocity=0, time=183),
#     Message('control_change', channel=0, control=64, value=0, time=1),
#     Message('note_on', channel=0, note=47, velocity=0, time=0),
#     Message('note_on', channel=0, note=57, velocity=0, time=2),
#     Message('note_on', channel=0, note=55, velocity=0, time=2),
#     Message('note_on', channel=0, note=64, velocity=0, time=1),
#     Message('note_on', channel=0, note=71, velocity=86, time=27),
#     Message('note_on', channel=0, note=40, velocity=101, time=1),
#     Message('note_on', channel=0, note=76, velocity=87, time=0),
#     Message('note_on', channel=0, note=28, velocity=98, time=2),
#     Message('note_on', channel=0, note=28, velocity=0, time=32),
#     Message('note_on', channel=0, note=40, velocity=0, time=8),
#     Message('note_on', channel=0, note=71, velocity=0, time=9),
#     Message('note_on', channel=0, note=76, velocity=0, time=4),
#     Message('note_on', channel=0, note=69, velocity=66, time=41),
#     Message('note_on', channel=0, note=71, velocity=69, time=100),
#     Message('note_on', channel=0, note=76, velocity=56, time=1),
#     Message('note_on', channel=0, note=69, velocity=0, time=10),
#     Message('note_on', channel=0, note=69, velocity=73, time=84),
#     Message('note_on', channel=0, note=71, velocity=0, time=4),
#     Message('note_on', channel=0, note=59, velocity=86, time=87),
#     Message('note_on', channel=0, note=52, velocity=78, time=2),
#     Message('note_on', channel=0, note=76, velocity=0, time=0),
#     Message('note_on', channel=0, note=56, velocity=80, time=1),
#     Message('note_on', channel=0, note=71, velocity=85, time=3),
#     Message('note_on', channel=0, note=76, velocity=81, time=3),
#     Message('control_change', channel=0, control=64, value=127, time=47),
#     Message('note_on', channel=0, note=69, velocity=0, time=130),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=71, velocity=81, time=11),
#     Message('control_change', channel=0, control=64, value=0, time=8),
#     Message('note_on', channel=0, note=52, velocity=0, time=4),
#     Message('note_on', channel=0, note=59, velocity=0, time=1),
#     Message('note_on', channel=0, note=76, velocity=0, time=2),
#     Message('note_on', channel=0, note=56, velocity=0, time=4),
#     Message('note_on', channel=0, note=71, velocity=0, time=55),
#     Message('note_on', channel=0, note=45, velocity=96, time=21),
#     Message('note_on', channel=0, note=33, velocity=90, time=0),
#     Message('note_on', channel=0, note=69, velocity=84, time=3),
#     Message('note_on', channel=0, note=45, velocity=0, time=34),
#     Message('note_on', channel=0, note=33, velocity=0, time=1),
#     Message('note_on', channel=0, note=76, velocity=62, time=67),
#     Message('note_on', channel=0, note=71, velocity=77, time=1),
#     Message('note_on', channel=0, note=69, velocity=0, time=1),
#     Message('note_on', channel=0, note=71, velocity=0, time=72),
#     Message('note_on', channel=0, note=69, velocity=75, time=19),
#     Message('note_on', channel=0, note=76, velocity=0, time=27),
#     Message('note_on', channel=0, note=69, velocity=0, time=17),
#     Message('note_on', channel=0, note=52, velocity=75, time=57),
#     Message('note_on', channel=0, note=71, velocity=83, time=1),
#     Message('note_on', channel=0, note=76, velocity=72, time=0),
#     Message('note_on', channel=0, note=71, velocity=0, time=90),
#     Message('note_on', channel=0, note=69, velocity=74, time=1),
#     Message('note_on', channel=0, note=52, velocity=0, time=61),
#     Message('note_on', channel=0, note=76, velocity=0, time=41),
#     Message('note_on', channel=0, note=57, velocity=81, time=4),
#     Message('note_on', channel=0, note=61, velocity=79, time=0),
#     Message('note_on', channel=0, note=74, velocity=87, time=0),
#     Message('note_on', channel=0, note=76, velocity=86, time=0),
#     Message('note_on', channel=0, note=55, velocity=75, time=1),
#     Message('note_on', channel=0, note=69, velocity=0, time=28),
#     Message('note_on', channel=0, note=61, velocity=0, time=60),
#     Message('control_change', channel=0, control=64, value=127, time=15),
#     Message('note_on', channel=0, note=52, velocity=79, time=85),
#     Message('note_on', channel=0, note=71, velocity=82, time=8),
#     Message('note_on', channel=0, note=57, velocity=0, time=22),
#     Message('note_on', channel=0, note=55, velocity=0, time=15),
#     Message('note_on', channel=0, note=52, velocity=0, time=5),
#     Message('note_on', channel=0, note=74, velocity=0, time=3),
#     Message('note_on', channel=0, note=76, velocity=0, time=0),
#     Message('note_on', channel=0, note=71, velocity=0, time=5),
#     Message('control_change', channel=0, control=64, value=0, time=2),
#     Message('note_on', channel=0, note=28, velocity=94, time=142),
#     Message('note_on', channel=0, note=40, velocity=90, time=0),
#     Message('note_on', channel=0, note=71, velocity=90, time=1),
#     Message('note_on', channel=0, note=40, velocity=0, time=39),
#     Message('control_change', channel=0, control=64, value=127, time=11),
#     Message('note_on', channel=0, note=28, velocity=0, time=23),
#     Message('note_on', channel=0, note=69, velocity=78, time=21),
#     Message('control_change', channel=0, control=64, value=0, time=5),
#     Message('note_on', channel=0, note=71, velocity=0, time=4),
#     Message('note_on', channel=0, note=69, velocity=0, time=70),
#     Message('note_on', channel=0, note=71, velocity=81, time=20),
#     Message('note_on', channel=0, note=76, velocity=68, time=2),
#     Message('note_on', channel=0, note=71, velocity=0, time=36),
#     Message('note_on', channel=0, note=76, velocity=0, time=42),
#     Message('note_on', channel=0, note=69, velocity=79, time=8),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=59, velocity=85, time=63),
#     Message('note_on', channel=0, note=52, velocity=81, time=0),
#     Message('note_on', channel=0, note=56, velocity=79, time=1),
#     Message('note_on', channel=0, note=71, velocity=88, time=1),
#     Message('note_on', channel=0, note=76, velocity=75, time=3),
#     Message('note_on', channel=0, note=76, velocity=0, time=6),
#     Message('control_change', channel=0, control=64, value=127, time=46),
#     Message('note_on', channel=0, note=71, velocity=0, time=31),
# ...
#     Message('note_on', channel=0, note=71, velocity=0, time=123),
#     Message('note_on', channel=0, note=74, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=85, time=4),
#     Message('note_on', channel=0, note=74, velocity=79, time=2),
#     Message('note_on', channel=0, note=67, velocity=77, time=0),
#     Message('note_on', channel=0, note=71, velocity=79, time=1),
#     Message('note_on', channel=0, note=50, velocity=74, time=98),
#     Message('note_on', channel=0, note=67, velocity=0, time=87),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=74, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=89, time=4),
#     Message('note_on', channel=0, note=79, velocity=88, time=1),
#     Message('note_on', channel=0, note=74, velocity=69, time=0),
#     Message('note_on', channel=0, note=71, velocity=83, time=1),
#     Message('note_on', channel=0, note=31, velocity=0, time=63),
#     Message('note_on', channel=0, note=59, velocity=82, time=37),
#     Message('note_on', channel=0, note=55, velocity=71, time=2),
#     Message('note_on', channel=0, note=50, velocity=0, time=176),
#     Message('note_on', channel=0, note=50, velocity=75, time=9),
#     Message('note_on', channel=0, note=43, velocity=0, time=123),
#     Message('note_on', channel=0, note=55, velocity=0, time=0),
#     Message('note_on', channel=0, note=59, velocity=0, time=1),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=0),
#     Message('note_on', channel=0, note=50, velocity=0, time=1),
#     Message('note_on', channel=0, note=79, velocity=0, time=0),
#     Message('control_change', channel=0, control=64, value=0, time=1),
#     Message('note_on', channel=0, note=74, velocity=0, time=11),
#     Message('note_on', channel=0, note=45, velocity=89, time=65),
#     Message('note_on', channel=0, note=33, velocity=84, time=3),
#     Message('note_on', channel=0, note=76, velocity=79, time=1),
#     Message('note_on', channel=0, note=69, velocity=73, time=2),
#     Message('note_on', channel=0, note=64, velocity=80, time=0),
#     Message('note_on', channel=0, note=73, velocity=73, time=2),
#     Message('note_on', channel=0, note=45, velocity=0, time=28),
#     Message('control_change', channel=0, control=64, value=127, time=14),
#     Message('note_on', channel=0, note=64, velocity=0, time=16),
#     Message('note_on', channel=0, note=33, velocity=0, time=23),
#     Message('note_on', channel=0, note=69, velocity=0, time=0),
#     Message('note_on', channel=0, note=73, velocity=0, time=0),
#     Message('note_on', channel=0, note=76, velocity=0, time=0),
#     Message('note_on', channel=0, note=64, velocity=78, time=2),
#     Message('note_on', channel=0, note=76, velocity=85, time=2),
#     Message('note_on', channel=0, note=69, velocity=77, time=0),
#     Message('note_on', channel=0, note=73, velocity=82, time=1),
#     Message('note_on', channel=0, note=33, velocity=73, time=4),
#     Message('note_on', channel=0, note=76, velocity=0, time=83),
#     Message('note_on', channel=0, note=33, velocity=0, time=8),
#     Message('note_on', channel=0, note=64, velocity=0, time=0),
#     Message('note_on', channel=0, note=69, velocity=0, time=0),
#     Message('note_on', channel=0, note=73, velocity=0, time=0),
#     Message('note_on', channel=0, note=76, velocity=94, time=2),
#     Message('note_on', channel=0, note=64, velocity=90, time=2),
#     Message('note_on', channel=0, note=33, velocity=81, time=0),
#     Message('note_on', channel=0, note=45, velocity=82, time=0),
#     Message('note_on', channel=0, note=69, velocity=72, time=0),
#     Message('note_on', channel=0, note=73, velocity=81, time=0),
#     Message('note_on', channel=0, note=33, velocity=0, time=180),
#     Message('note_on', channel=0, note=45, velocity=0, time=0),
#     Message('note_on', channel=0, note=64, velocity=0, time=0),
#     Message('note_on', channel=0, note=57, velocity=91, time=4),
#     Message('note_on', channel=0, note=64, velocity=91, time=3),
#     Message('note_on', channel=0, note=69, velocity=0, time=1),
#     Message('note_on', channel=0, note=73, velocity=0, time=0),
#     Message('note_on', channel=0, note=76, velocity=0, time=0),
#     Message('note_on', channel=0, note=33, velocity=81, time=0),
#     Message('note_on', channel=0, note=61, velocity=86, time=1),
#     Message('note_on', channel=0, note=45, velocity=84, time=2),
#     Message('note_on', channel=0, note=76, velocity=90, time=2),
#     Message('note_on', channel=0, note=69, velocity=79, time=1),
#     Message('note_on', channel=0, note=73, velocity=86, time=3),
#     Message('control_change', channel=0, control=64, value=0, time=101),
#     Message('note_on', channel=0, note=67, velocity=75, time=69),
#     Message('note_on', channel=0, note=33, velocity=0, time=22),
#     Message('note_on', channel=0, note=57, velocity=0, time=2),
#     Message('note_on', channel=0, note=45, velocity=0, time=0),
#     Message('note_on', channel=0, note=69, velocity=0, time=0),
#     Message('note_on', channel=0, note=61, velocity=0, time=1),
#     Message('note_on', channel=0, note=76, velocity=0, time=0),
#     Message('note_on', channel=0, note=73, velocity=0, time=0),
#     Message('note_on', channel=0, note=64, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=7),
#     Message('note_on', channel=0, note=79, velocity=88, time=83),
#     Message('note_on', channel=0, note=67, velocity=84, time=1),
#     Message('note_on', channel=0, note=50, velocity=86, time=0),
#     Message('note_on', channel=0, note=38, velocity=85, time=1),
#     Message('note_on', channel=0, note=74, velocity=77, time=1),
#     Message('note_on', channel=0, note=72, velocity=80, time=2),
#     Message('control_change', channel=0, control=64, value=127, time=46),
#     Message('note_on', channel=0, note=67, velocity=0, time=139),
#     Message('note_on', channel=0, note=72, velocity=0, time=0),
#     Message('note_on', channel=0, note=74, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=86, time=6),
#     Message('note_on', channel=0, note=79, velocity=92, time=4),
#     Message('note_on', channel=0, note=72, velocity=79, time=1),
#     Message('note_on', channel=0, note=74, velocity=77, time=0),
#     Message('note_on', channel=0, note=50, velocity=0, time=81),
#     Message('note_on', channel=0, note=50, velocity=86, time=4),
#     Message('note_on', channel=0, note=67, velocity=0, time=96),
#     Message('note_on', channel=0, note=72, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=85, time=9),
#     Message('note_on', channel=0, note=79, velocity=90, time=0),
#     Message('note_on', channel=0, note=72, velocity=78, time=1),
#     Message('note_on', channel=0, note=60, velocity=83, time=90),
#     Message('note_on', channel=0, note=57, velocity=83, time=1),
#     Message('note_on', channel=0, note=54, velocity=81, time=2),
#     Message('note_on', channel=0, note=50, velocity=0, time=181),
#     Message('note_on', channel=0, note=79, velocity=0, time=7),
#     Message('note_on', channel=0, note=50, velocity=76, time=1),
#     Message('note_on', channel=0, note=79, velocity=90, time=4),
#     Message('note_on', channel=0, note=76, velocity=73, time=98),
#     Message('control_change', channel=0, control=64, value=0, time=49),
#     Message('note_on', channel=0, note=67, velocity=0, time=2),
#     Message('note_on', channel=0, note=60, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=0, time=0),
#     Message('note_on', channel=0, note=54, velocity=0, time=2),
#     Message('note_on', channel=0, note=57, velocity=0, time=0),
#     Message('note_on', channel=0, note=50, velocity=0, time=0),
#     Message('note_on', channel=0, note=72, velocity=0, time=1),
#     Message('note_on', channel=0, note=76, velocity=0, time=4),
#     Message('note_on', channel=0, note=38, velocity=0, time=1),
#     Message('note_on', channel=0, note=74, velocity=0, time=15),
#     Message('note_on', channel=0, note=52, velocity=94, time=20),
#     Message('note_on', channel=0, note=40, velocity=82, time=2),
#     Message('note_on', channel=0, note=79, velocity=87, time=2),
#     Message('note_on', channel=0, note=52, velocity=0, time=39),
#     Message('note_on', channel=0, note=40, velocity=0, time=1),
#     Message('note_on', channel=0, note=76, velocity=78, time=54),
#     Message('note_on', channel=0, note=79, velocity=0, time=36),
#     Message('note_on', channel=0, note=76, velocity=0, time=57),
#     Message('note_on', channel=0, note=79, velocity=83, time=7),
#     Message('note_on', channel=0, note=76, velocity=73, time=96),
#     Message('note_on', channel=0, note=79, velocity=0, time=93),
#     Message('note_on', channel=0, note=64, velocity=81, time=6),
#     Message('note_on', channel=0, note=79, velocity=89, time=1),
#     Message('note_on', channel=0, note=56, velocity=77, time=1),
#     Message('note_on', channel=0, note=59, velocity=75, time=2),
#     Message('note_on', channel=0, note=76, velocity=0, time=98),
#     Message('note_on', channel=0, note=76, velocity=82, time=9),
#     Message('note_on', channel=0, note=64, velocity=0, time=3),
#     Message('note_on', channel=0, note=56, velocity=0, time=6),
#     Message('note_on', channel=0, note=79, velocity=0, time=16),
#     Message('note_on', channel=0, note=59, velocity=0, time=19),
#     Message('note_on', channel=0, note=47, velocity=92, time=140),
#     Message('note_on', channel=0, note=35, velocity=80, time=2),
#     Message('control_change', channel=0, control=64, value=127, time=50),
#     Message('note_on', channel=0, note=71, velocity=72, time=143),
#     Message('note_on', channel=0, note=76, velocity=0, time=34),
#     Message('note_on', channel=0, note=35, velocity=0, time=9),
#     Message('note_on', channel=0, note=47, velocity=0, time=3),
#     Message('control_change', channel=0, control=64, value=0, time=3),
#     Message('note_on', channel=0, note=71, velocity=0, time=31),
#     Message('note_on', channel=0, note=54, velocity=83, time=8),
#     Message('note_on', channel=0, note=71, velocity=81, time=1),
#     Message('note_on', channel=0, note=71, velocity=0, time=39),
#     Message('note_on', channel=0, note=54, velocity=0, time=37),
#     Message('note_on', channel=0, note=71, velocity=70, time=20),
#     Message('control_change', channel=0, control=64, value=127, time=10),
#     Message('note_on', channel=0, note=73, velocity=81, time=85),
#     Message('note_on', channel=0, note=63, velocity=79, time=2),
#     Message('note_on', channel=0, note=57, velocity=80, time=0),
#     Message('note_on', channel=0, note=76, velocity=76, time=92),
#     Message('note_on', channel=0, note=54, velocity=84, time=95),
#     Message('control_change', channel=0, control=64, value=0, time=76),
#     Message('note_on', channel=0, note=54, velocity=0, time=9),
#     Message('note_on', channel=0, note=63, velocity=0, time=1),
#     Message('note_on', channel=0, note=57, velocity=0, time=1),
#     Message('note_on', channel=0, note=71, velocity=0, time=1),
#     Message('note_on', channel=0, note=76, velocity=0, time=2),
#     Message('note_on', channel=0, note=73, velocity=0, time=1),
#     Message('note_on', channel=0, note=80, velocity=94, time=20),
#     Message('note_on', channel=0, note=40, velocity=83, time=101),
#     Message('note_on', channel=0, note=28, velocity=83, time=1),
#     Message('note_on', channel=0, note=76, velocity=84, time=99),
#     Message('control_change', channel=0, control=64, value=127, time=52),
#     Message('note_on', channel=0, note=52, velocity=81, time=233),
#     Message('note_on', channel=0, note=59, velocity=82, time=1),
#     Message('note_on', channel=0, note=56, velocity=78, time=5),
#     Message('note_on', channel=0, note=95, velocity=95, time=2),
#     Message('note_on', channel=0, note=92, velocity=87, time=8),
#     Message('note_on', channel=0, note=88, velocity=75, time=85),
#     Message('note_on', channel=0, note=92, velocity=0, time=80),
#     Message('note_on', channel=0, note=95, velocity=0, time=0),
#     Message('note_on', channel=0, note=92, velocity=79, time=7),
#     Message('note_on', channel=0, note=95, velocity=89, time=3),
#     Message('note_on', channel=0, note=40, velocity=0, time=27),
#     Message('control_change', channel=0, control=64, value=0, time=8),
#     Message('note_on', channel=0, note=28, velocity=0, time=9),
#     Message('note_on', channel=0, note=56, velocity=0, time=3),
#     Message('note_on', channel=0, note=80, velocity=0, time=5),
#     Message('note_on', channel=0, note=59, velocity=0, time=2),
#     Message('note_on', channel=0, note=88, velocity=0, time=2),
#     Message('note_on', channel=0, note=52, velocity=0, time=19),
#     Message('note_on', channel=0, note=45, velocity=86, time=4),
#     Message('note_on', channel=0, note=33, velocity=83, time=0),
#     Message('note_on', channel=0, note=76, velocity=0, time=4),
#     Message('note_on', channel=0, note=92, velocity=0, time=0),
#     Message('control_change', channel=0, control=64, value=127, time=61),
#     Message('note_on', channel=0, note=97, velocity=96, time=44),
#     Message('note_on', channel=0, note=93, velocity=74, time=5),
#     Message('note_on', channel=0, note=52, velocity=78, time=185),
#     Message('note_on', channel=0, note=57, velocity=80, time=202),
#     Message('note_on', channel=0, note=61, velocity=81, time=4),
#     Message('note_on', channel=0, note=83, velocity=94, time=2),
#     Message('note_on', channel=0, note=81, velocity=89, time=115),
#     Message('note_on', channel=0, note=52, velocity=0, time=50),
#     Message('note_on', channel=0, note=52, velocity=74, time=5),
#     Message('note_on', channel=0, note=79, velocity=92, time=113),
#     Message('control_change', channel=0, control=64, value=0, time=3),
#     Message('note_on', channel=0, note=33, velocity=0, time=6),
#     Message('note_on', channel=0, note=61, velocity=0, time=2),
#     Message('note_on', channel=0, note=80, velocity=95, time=1),
#     Message('note_on', channel=0, note=52, velocity=0, time=0),
#     Message('note_on', channel=0, note=45, velocity=0, time=0),
#     Message('note_on', channel=0, note=83, velocity=0, time=2),
#     Message('note_on', channel=0, note=93, velocity=0, time=0),
#     Message('note_on', channel=0, note=97, velocity=0, time=1),
#     Message('note_on', channel=0, note=57, velocity=0, time=0),
#     Message('note_on', channel=0, note=81, velocity=0, time=1),
#     Message('note_on', channel=0, note=95, velocity=0, time=4),
#     Message('note_on', channel=0, note=40, velocity=93, time=66),
#     Message('note_on', channel=0, note=28, velocity=99, time=1),
#     Message('control_change', channel=0, control=64, value=127, time=48),
#     Message('note_on', channel=0, note=76, velocity=87, time=79),
#     Message('note_on', channel=0, note=76, velocity=0, time=190),
#     Message('note_on', channel=0, note=76, velocity=94, time=4),
#     Message('note_on', channel=0, note=40, velocity=0, time=22),
#     Message('control_change', channel=0, control=64, value=0, time=10),
#     Message('note_on', channel=0, note=80, velocity=0, time=18),
#     Message('note_on', channel=0, note=52, velocity=79, time=25),
#     Message('note_on', channel=0, note=59, velocity=78, time=1),
#     Message('note_on', channel=0, note=68, velocity=74, time=0),
#     Message('note_on', channel=0, note=55, velocity=64, time=9),
#     Message('note_on', channel=0, note=76, velocity=0, time=1),
#     Message('note_on', channel=0, note=28, velocity=0, time=10),
#     Message('note_on', channel=0, note=55, velocity=0, time=0),
#     Message('note_on', channel=0, note=79, velocity=0, time=0),
#     Message('note_on', channel=0, note=52, velocity=0, time=1505),
#     Message('note_on', channel=0, note=59, velocity=0, time=3080),
#     Message('note_on', channel=0, note=68, velocity=0, time=0),
#     MetaMessage('end_of_track', time=1)])
# ])

# %%
def extract_notes_from_midi(file_path):
    midi_file = mido.MidiFile(file_path)
    notes = []
    for msg in midi_file:
        if msg.type == 'note_on':
            notes.append({
                'pitch': msg.note,
                'start_time': msg.time,
                'velocity': msg.velocity
            })
    return notes

# %%
data_label_path = "midis/label.csv"

# %%
label_df = pd.read_csv(data_label_path)

# %%
# change label_df to a dictionary
label_dict = {}
for i in range(len(label_df)):
    label_dict[label_df.iloc[i,0]] = label_df.iloc[i,1]

label_dict
# Out:
# {'Q1_0vLPYiPN7qY_0': 1,
#  'Q1_0vLPYiPN7qY_1': 1,
#  'Q1_0vLPYiPN7qY_2': 1,
#  'Q1_1Qc15G0ZHIg_1': 1,
#  'Q1_1Qc15G0ZHIg_2': 1,
#  'Q1_1Qc15G0ZHIg_3': 1,
#  'Q1_1vjy9oMFa8c_2': 1,
#  'Q1_1vjy9oMFa8c_4': 1,
#  'Q1_1vjy9oMFa8c_5': 1,
#  'Q1_2Z9SjI131jA_0': 1,
#  'Q1_2Z9SjI131jA_1': 1,
#  'Q1_2Z9SjI131jA_10': 1,
#  'Q1_2Z9SjI131jA_11': 1,
#  'Q1_2Z9SjI131jA_12': 1,
#  'Q1_2Z9SjI131jA_13': 1,
#  'Q1_2Z9SjI131jA_14': 1,
#  'Q1_2Z9SjI131jA_15': 1,
#  'Q1_2Z9SjI131jA_2': 1,
#  'Q1_2Z9SjI131jA_3': 1,
#  'Q1_2Z9SjI131jA_4': 1,
#  'Q1_2Z9SjI131jA_7': 1,
#  'Q1_2Z9SjI131jA_8': 1,
#  'Q1_2Z9SjI131jA_9': 1,
#  'Q1_3N2G21U7guk_3': 1,
#  'Q1_3N2G21U7guk_5': 1,
#  'Q1_3N2G21U7guk_6': 1,
#  'Q1_3ahg_eQZhxs_0': 1,
#  'Q1_3ahg_eQZhxs_1': 1,
#  'Q1_4dXC1cC7crw_0': 1,
#  'Q1_4dXC1cC7crw_1': 1,
#  'Q1_4ydjOX3pWds_0': 1,
#  'Q1_4ydjOX3pWds_1': 1,
#  'Q1_5Ju9q1N2x0E_2': 1,
#  'Q1_5NW0zDu6IYM_2': 1,
#  'Q1_60LLKmpgzRM_0': 1,
#  'Q1_6Uf9XBUD3wE_0': 1,
#  'Q1_6Uf9XBUD3wE_1': 1,
#  'Q1_6kRPHamGDSo_0': 1,
#  'Q1_6kRPHamGDSo_1': 1,
#  'Q1_6kRPHamGDSo_3': 1,
#  'Q1_6wFJhmhNeeg_0': 1,
#  'Q1_7yW9c7t8Hq0_1': 1,
#  'Q1_7yW9c7t8Hq0_2': 1,
#  'Q1_7yW9c7t8Hq0_3': 1,
#  'Q1_8izVTDgBQPc_0': 1,
#  'Q1_8izVTDgBQPc_1': 1,
#  'Q1_8rupdevqfuI_0': 1,
#  'Q1_8rupdevqfuI_1': 1,
#  'Q1_8rupdevqfuI_2': 1,
#  'Q1_94ROf10d1iA_0': 1,
#  'Q1_94ROf10d1iA_1': 1,
#  'Q1_94ROf10d1iA_2': 1,
#  'Q1_94ROf10d1iA_3': 1,
#  'Q1_9Yb9OEVwups_0': 1,
#  'Q1_9v2WSpn4FCw_0': 1,
#  'Q1_9v2WSpn4FCw_1': 1,
#  'Q1_9v2WSpn4FCw_10': 1,
#  'Q1_9v2WSpn4FCw_2': 1,
#  'Q1_9v2WSpn4FCw_5': 1,
#  'Q1_9v2WSpn4FCw_6': 1,
#  'Q1_ANZf1QXsNrY_0': 1,
#  'Q1_ANZf1QXsNrY_1': 1,
#  'Q1_ANZf1QXsNrY_2': 1,
#  'Q1_ANZf1QXsNrY_3': 1,
#  'Q1_ANZf1QXsNrY_4': 1,
#  'Q1_ANZf1QXsNrY_5': 1,
#  'Q1_BGf5nCdzPOc_0': 1,
#  'Q1_BGf5nCdzPOc_1': 1,
#  'Q1_Cg2u_Ldjv8g_0': 1,
#  'Q1_Cg2u_Ldjv8g_1': 1,
#  'Q1_DX1IK3z1w10_1': 1,
#  'Q1_Fc1qk52SaKY_0': 1,
#  'Q1_Fc1qk52SaKY_1': 1,
#  'Q1_FfwKrQyQ7WU_0': 1,
#  'Q1_FfwKrQyQ7WU_1': 1,
#  'Q1_FfwKrQyQ7WU_2': 1,
#  'Q1_FfwKrQyQ7WU_3': 1,
#  'Q1_GY3f6ckBVkA_0': 1,
#  'Q1_GY3f6ckBVkA_1': 1,
#  'Q1_GY3f6ckBVkA_2': 1,
#  'Q1_GY3f6ckBVkA_3': 1,
#  'Q1_GbUV3TXUzeQ_1': 1,
#  'Q1_GbUV3TXUzeQ_2': 1,
#  'Q1_HY9vPoHbgaI_0': 1,
#  'Q1_HY9vPoHbgaI_1': 1,
#  'Q1_HY9vPoHbgaI_2': 1,
#  'Q1_HY9vPoHbgaI_3': 1,
#  'Q1_IH2KrGjKXw0_3': 1,
#  'Q1_Ie5koh4qvJc_12': 1,
#  'Q1_Ie5koh4qvJc_6': 1,
#  'Q1_J6X3rVU1H-c_1': 1,
#  'Q1_J6X3rVU1H-c_2': 1,
#  'Q1_JT1XJnVmABo_2': 1,
#  'Q1_JT1XJnVmABo_3': 1,
#  'Q1_JT1XJnVmABo_4': 1,
#  'Q1_JT1XJnVmABo_5': 1,
#  'Q1_JYVXM0qNQAg_0': 1,
#  'Q1_JYVXM0qNQAg_2': 1,
#  'Q1_Jn9r0avp0fY_0': 1,
#  'Q1_Jn9r0avp0fY_1': 1,
#  'Q1_Jn9r0avp0fY_2': 1,
#  'Q1_Jn9r0avp0fY_3': 1,
#  'Q1_K6OFDxBU370_0': 1,
#  'Q1_K6OFDxBU370_1': 1,
#  'Q1_KxlqB3j0zys_0': 1,
#  'Q1_KxlqB3j0zys_1': 1,
#  'Q1_NGE9ynTJABg_0': 1,
#  'Q1_NGE9ynTJABg_1': 1,
#  'Q1_NGE9ynTJABg_2': 1,
#  'Q1_NP0lwB-_-og_1': 1,
#  'Q1_POaIGvLsp5M_0': 1,
#  'Q1_POaIGvLsp5M_1': 1,
#  'Q1_PdwxeMPXOCk_0': 1,
#  'Q1_PdwxeMPXOCk_1': 1,
#  'Q1_PdwxeMPXOCk_2': 1,
#  'Q1_QwsQ8ejbMKg_0': 1,
#  'Q1_QwsQ8ejbMKg_1': 1,
#  'Q1_RaUSISlnhKw_0': 1,
#  'Q1_RaUSISlnhKw_1': 1,
#  'Q1_RaUSISlnhKw_2': 1,
#  'Q1_SQDuF0qxGQw_0': 1,
#  'Q1_SQDuF0qxGQw_1': 1,
#  'Q1_SQDuF0qxGQw_2': 1,
#  'Q1_SlsXsqotUis_0': 1,
#  'Q1_T92R7xjce34_1': 1,
#  'Q1_TNoaOTrTkTQ_0': 1,
#  'Q1_TNoaOTrTkTQ_1': 1,
#  'Q1_TNoaOTrTkTQ_2': 1,
#  'Q1_UJcnNfeCN1c_2': 1,
#  'Q1_UJcnNfeCN1c_3': 1,
#  'Q1_UOSlDydo94E_0': 1,
#  'Q1_UOSlDydo94E_1': 1,
#  'Q1_UOSlDydo94E_2': 1,
#  'Q1_UYh88SRZC24_0': 1,
#  'Q1_UYh88SRZC24_1': 1,
#  'Q1_V3Y9L4UOcpk_2': 1,
#  'Q1_VXgRfsVd_o0_0': 1,
#  'Q1_VXgRfsVd_o0_1': 1,
#  'Q1_VXgRfsVd_o0_2': 1,
#  'Q1_WpZ1rWHOCAQ_0': 1,
#  'Q1_WpZ1rWHOCAQ_1': 1,
#  'Q1_WpZ1rWHOCAQ_2': 1,
#  'Q1_Wy2-my19YnY_0': 1,
#  'Q1_Wy2-my19YnY_1': 1,
#  'Q1_XC_SiJszQx0_3': 1,
#  'Q1_Xsn9zT-05ns_0': 1,
#  'Q1_Xsn9zT-05ns_1': 1,
#  'Q1_Y5JcZQ0xg4Y_0': 1,
#  'Q1_Y5JcZQ0xg4Y_1': 1,
#  'Q1_Y5JcZQ0xg4Y_2': 1,
#  'Q1_Y5JcZQ0xg4Y_3': 1,
#  'Q1_ZgT7yq2jsBk_0': 1,
#  'Q1__8v0MFBZoco_0': 1,
#  'Q1__8v0MFBZoco_1': 1,
#  'Q1__BK2o77sTc0_0': 1,
#  'Q1__BK2o77sTc0_1': 1,
#  'Q1__SJQaaRzD-A_0': 1,
#  'Q1__SJQaaRzD-A_1': 1,
#  'Q1__kJtgm1OUNA_0': 1,
#  'Q1__kJtgm1OUNA_1': 1,
#  'Q1__kJtgm1OUNA_2': 1,
#  'Q1_aYe-2Glruu4_0': 1,
#  'Q1_aYe-2Glruu4_1': 1,
#  'Q1_aYe-2Glruu4_3': 1,
#  'Q1_aYe-2Glruu4_4': 1,
#  'Q1_bIx4DwkZxFY_0': 1,
#  'Q1_bIx4DwkZxFY_1': 1,
#  'Q1_bIx4DwkZxFY_2': 1,
#  'Q1_bQS8eAXAhyE_0': 1,
#  'Q1_bQS8eAXAhyE_1': 1,
#  'Q1_bQS8eAXAhyE_2': 1,
#  'Q1_biROWEwkDQQ_3': 1,
#  'Q1_cB-Xh8H_7-Q_0': 1,
#  'Q1_dfNdpy8TUzA_0': 1,
#  'Q1_dfNdpy8TUzA_1': 1,
#  'Q1_dfNdpy8TUzA_2': 1,
#  'Q1_doM_LWo-74A_0': 1,
#  'Q1_doM_LWo-74A_1': 1,
#  'Q1_doM_LWo-74A_2': 1,
#  'Q1_doM_LWo-74A_3': 1,
#  'Q1_doM_LWo-74A_4': 1,
#  'Q1_e838BE_MH6s_1': 1,
#  'Q1_e838BE_MH6s_2': 1,
#  'Q1_e838BE_MH6s_3': 1,
#  'Q1_e838BE_MH6s_4': 1,
#  'Q1_e8NQ2NH0nc8_0': 1,
#  'Q1_e8NQ2NH0nc8_1': 1,
#  'Q1_eVMSeElk81Q_0': 1,
#  'Q1_eVMSeElk81Q_1': 1,
#  'Q1_eVMSeElk81Q_2': 1,
#  'Q1_fey-8bOR95E_0': 1,
#  'Q1_fey-8bOR95E_1': 1,
#  'Q1_fey-8bOR95E_2': 1,
#  'Q1_fey-8bOR95E_3': 1,
#  'Q1_gSwv8hZGM-s_0': 1,
#  'Q1_gSwv8hZGM-s_1': 1,
#  'Q1_gwmVjvR-sVs_0': 1,
#  'Q1_gwmVjvR-sVs_1': 1,
#  'Q1_iFgSjUqI7iM_0': 1,
#  'Q1_iFgSjUqI7iM_1': 1,
#  'Q1_im4Qxn3GQvo_0': 1,
#  'Q1_im4Qxn3GQvo_1': 1,
#  'Q1_im4Qxn3GQvo_2': 1,
#  'Q1_jziI_cuN_H8_0': 1,
#  'Q1_jziI_cuN_H8_1': 1,
#  'Q1_jziI_cuN_H8_2': 1,
#  'Q1_k4dxAlI5N-k_0': 1,
#  'Q1_k4dxAlI5N-k_1': 1,
#  'Q1_ldCQ6N9G6Mk_2': 1,
#  'Q1_mX-xs3OVhTs_0': 1,
#  'Q1_mX-xs3OVhTs_1': 1,
#  'Q1_miqLU2739dk_1': 1,
#  'Q1_nOIBJHkqrE8_0': 1,
#  'Q1_o5AIp2Yc01M_0': 1,
#  'Q1_o5AIp2Yc01M_1': 1,
#  'Q1_osxmQReE_2o_0': 1,
#  'Q1_pNwQ9Tu_bCs_0': 1,
#  'Q1_pNwQ9Tu_bCs_1': 1,
#  'Q1_pNwQ9Tu_bCs_2': 1,
#  'Q1_qlbazHayULg_8': 1,
#  'Q1_r6laJv1-HMg_0': 1,
#  'Q1_s5b8viFsVJE_0': 1,
#  'Q1_s5b8viFsVJE_1': 1,
#  'Q1_s5b8viFsVJE_2': 1,
#  'Q1_s6-SbDSZzEU_0': 1,
#  'Q1_s6-SbDSZzEU_1': 1,
#  'Q1_sUJ4a74Skk8_0': 1,
#  'Q1_sZe3IB1OVfw_0': 1,
#  'Q1_sZe3IB1OVfw_1': 1,
#  'Q1_uqRLEByE6pU_0': 1,
#  'Q1_uqRLEByE6pU_1': 1,
#  'Q1_uqRLEByE6pU_2': 1,
#  'Q1_vv6nrZ2myXw_0': 1,
#  'Q1_vv6nrZ2myXw_1': 1,
#  'Q1_vv6nrZ2myXw_2': 1,
#  'Q1_vv6nrZ2myXw_3': 1,
#  'Q1_vv6nrZ2myXw_4': 1,
#  'Q1_wnB2cjd6zbE_0': 1,
#  'Q1_xrhWli_R98g_1': 1,
#  'Q1_xrhWli_R98g_3': 1,
#  'Q1_yFw_kO7DF-Y_0': 1,
#  'Q1_yFw_kO7DF-Y_1': 1,
#  'Q1_yFw_kO7DF-Y_2': 1,
#  'Q1_zHwJG8Rrx6c_0': 1,
#  'Q1_zHwJG8Rrx6c_1': 1,
#  'Q1_zHwJG8Rrx6c_2': 1,
#  'Q1_zHwJG8Rrx6c_3': 1,
#  'Q1_zmZHNy9T8Pg_0': 1,
#  'Q1_zmZHNy9T8Pg_1': 1,
#  'Q1_zmZHNy9T8Pg_2': 1,
#  'Q2_--2B4d4lQhs_0': 2,
#  'Q2_--2B4d4lQhs_1': 2,
#  'Q2_--2B4d4lQhs_2': 2,
#  'Q2_-jJVb0xvbdg_0': 2,
#  'Q2_-jJVb0xvbdg_1': 2,
#  'Q2_08t73Qgjkt4_0': 2,
#  'Q2_08t73Qgjkt4_1': 2,
#  'Q2_08t73Qgjkt4_2': 2,
#  'Q2_0H4rq0L9OSw_0': 2,
#  'Q2_0H4rq0L9OSw_1': 2,
#  'Q2_0J7lX-Tcx-w_0': 2,
#  'Q2_0J7lX-Tcx-w_1': 2,
#  'Q2_0J7lX-Tcx-w_2': 2,
#  'Q2_0qYNvMCEwaw_0': 2,
#  'Q2_0v2N1ROvEI0_0': 2,
#  'Q2_0v2N1ROvEI0_1': 2,
#  'Q2_16OaOpfOPZ0_2': 2,
#  'Q2_16OaOpfOPZ0_3': 2,
#  'Q2_1EDThWjNxOI_0': 2,
#  'Q2_1EDThWjNxOI_1': 2,
#  'Q2_1Q3MoBFh6eU_1': 2,
#  'Q2_1TAKQK3s6qQ_0': 2,
#  'Q2_1kny88W533Q_0': 2,
#  'Q2_1kny88W533Q_2': 2,
#  'Q2_1kny88W533Q_3': 2,
#  'Q2_1kny88W533Q_4': 2,
#  'Q2_2uLw9Zs60A4_0': 2,
#  'Q2_38i12IPkL5c_0': 2,
#  'Q2_38i12IPkL5c_1': 2,
#  'Q2_38i12IPkL5c_2': 2,
#  'Q2_3ZnxqCZ7qGg_1': 2,
#  'Q2_3ZnxqCZ7qGg_2': 2,
#  'Q2_3_MxhSS86oU_0': 2,
#  'Q2_3_MxhSS86oU_1': 2,
#  'Q2_48EYLEAgaBc_0': 2,
#  'Q2_48EYLEAgaBc_1': 2,
#  'Q2_5CEAeMiXKaA_0': 2,
#  'Q2_5NW0zDu6IYM_0': 2,
#  'Q2_5NW0zDu6IYM_1': 2,
#  'Q2_61EA0xRX8gE_0': 2,
#  'Q2_61EA0xRX8gE_1': 2,
#  'Q2_61EA0xRX8gE_3': 2,
#  'Q2_61EA0xRX8gE_4': 2,
#  'Q2_61EA0xRX8gE_5': 2,
#  'Q2_6n8HgIcJ6vo_0': 2,
#  'Q2_78C_TpQDvVE_0': 2,
#  'Q2_78C_TpQDvVE_1': 2,
#  'Q2_7n32BtYb4d4_0': 2,
#  'Q2_7n32BtYb4d4_1': 2,
#  'Q2_7n32BtYb4d4_2': 2,
#  'Q2_7n32BtYb4d4_3': 2,
#  'Q2_8TYY0qG-KOw_1': 2,
#  'Q2_8c7kcmsnf-s_0': 2,
#  'Q2_8c7kcmsnf-s_1': 2,
#  'Q2_8c7kcmsnf-s_2': 2,
#  'Q2_9v2WSpn4FCw_1': 2,
#  'Q2_9v2WSpn4FCw_2': 2,
#  'Q2_9v2WSpn4FCw_3': 2,
#  'Q2_9v2WSpn4FCw_4': 2,
#  'Q2_9v2WSpn4FCw_5': 2,
#  'Q2_9v2WSpn4FCw_6': 2,
#  'Q2_9v2WSpn4FCw_7': 2,
#  'Q2_9v2WSpn4FCw_8': 2,
#  'Q2_ANZf1QXsNrY_6': 2,
#  'Q2_ANZf1QXsNrY_7': 2,
#  'Q2_AWNbcxXDmt0_0': 2,
#  'Q2_AacIP9mDLw8_0': 2,
#  'Q2_AacIP9mDLw8_2': 2,
#  'Q2_BzqX-9TA-GY_1': 2,
#  'Q2_BzqX-9TA-GY_2': 2,
#  'Q2_CxFXrYgdSSI_0': 2,
#  'Q2_CxFXrYgdSSI_1': 2,
#  'Q2_CxFXrYgdSSI_2': 2,
#  'Q2_D-gDPh9ZpFk_0': 2,
#  'Q2_D-gDPh9ZpFk_1': 2,
#  'Q2_D-gDPh9ZpFk_2': 2,
#  'Q2_D5kyjnlDNZs_0': 2,
#  'Q2_D5kyjnlDNZs_1': 2,
#  'Q2_D5kyjnlDNZs_2': 2,
#  'Q2_DYBBfpEx-JI_0': 2,
#  'Q2_DYBBfpEx-JI_1': 2,
#  'Q2_DYBBfpEx-JI_2': 2,
#  'Q2_DYBBfpEx-JI_3': 2,
#  'Q2_Dg935IbDggo_0': 2,
#  'Q2_Dg935IbDggo_1': 2,
#  'Q2_Dg935IbDggo_2': 2,
#  'Q2_Dg935IbDggo_3': 2,
#  'Q2_DhnX54kOW8U_0': 2,
#  'Q2_EtAbPc20mn8_0': 2,
#  'Q2_FUAK5TBaNY8_1': 2,
#  'Q2_GwdQliEv6Z0_0': 2,
#  'Q2_GwdQliEv6Z0_1': 2,
#  'Q2_Ie5koh4qvJc_10': 2,
#  'Q2_Ie5koh4qvJc_11': 2,
#  'Q2_Ie5koh4qvJc_13': 2,
#  'Q2_Ie5koh4qvJc_26': 2,
#  'Q2_Ie5koh4qvJc_30': 2,
#  'Q2_Ie5koh4qvJc_7': 2,
#  'Q2_Ie5koh4qvJc_9': 2,
#  'Q2_Iq6g_4AwUWs_0': 2,
#  'Q2_Iq6g_4AwUWs_1': 2,
#  'Q2_ItGNJM6skM4_1': 2,
#  'Q2_ItGNJM6skM4_2': 2,
#  'Q2_JMt4m608s3k_0': 2,
#  'Q2_JMt4m608s3k_1': 2,
#  'Q2_JMt4m608s3k_2': 2,
#  'Q2_JT1XJnVmABo_6': 2,
#  'Q2_JYVXM0qNQAg_1': 2,
#  'Q2_Kk60F8a7-Jw_0': 2,
#  'Q2_L3_TadjSQQ0_0': 2,
#  'Q2_L3_TadjSQQ0_1': 2,
#  'Q2_OCqMDeD6Fmc_0': 2,
#  'Q2_OCqMDeD6Fmc_1': 2,
#  'Q2_OCqMDeD6Fmc_2': 2,
#  'Q2_OCqMDeD6Fmc_3': 2,
#  'Q2_P-We4q3goKU_1': 2,
#  'Q2_P-We4q3goKU_2': 2,
#  'Q2_P-We4q3goKU_3': 2,
#  'Q2_P-We4q3goKU_4': 2,
#  'Q2_P-We4q3goKU_5': 2,
#  'Q2_P-We4q3goKU_6': 2,
#  'Q2_PZN7XLKzLDI_0': 2,
#  'Q2_Q5b5unyP8BM_0': 2,
#  'Q2_Q5b5unyP8BM_1': 2,
#  'Q2_QmK_SND2jAw_0': 2,
#  'Q2_QmK_SND2jAw_1': 2,
#  'Q2_REq37pDAm3A_2': 2,
#  'Q2_RiQMuhk_SuQ_1': 2,
#  'Q2_RiQMuhk_SuQ_2': 2,
#  'Q2_RiQMuhk_SuQ_3': 2,
#  'Q2_S1T3UF1vhSk_1': 2,
#  'Q2_S1T3UF1vhSk_2': 2,
#  'Q2_S7Bo4-NCEDk_0': 2,
#  'Q2_S7Bo4-NCEDk_1': 2,
#  'Q2_S7Bo4-NCEDk_2': 2,
#  'Q2_TcFVq0leii4_1': 2,
#  'Q2_TcFVq0leii4_2': 2,
#  'Q2_UAm0aWvzFI8_0': 2,
#  'Q2_UAm0aWvzFI8_1': 2,
#  'Q2_UE0y8MHqT-g_1': 2,
#  'Q2_UE0y8MHqT-g_2': 2,
#  'Q2_UJcnNfeCN1c_1': 2,
#  'Q2_UTo7E0evQWw_0': 2,
#  'Q2_Uu-oRTRT6uQ_0': 2,
#  'Q2_Uu-oRTRT6uQ_1': 2,
#  'Q2_Uu-oRTRT6uQ_2': 2,
#  'Q2_WBxql6cuU7c_0': 2,
#  'Q2_WQrPcuy50aA_0': 2,
#  'Q2_WQrPcuy50aA_1': 2,
#  'Q2_XC_SiJszQx0_1': 2,
#  'Q2_XfA2KXodrOE_0': 2,
#  'Q2_XfA2KXodrOE_1': 2,
#  'Q2_ZTrEoB8T9YA_0': 2,
#  'Q2_ZTrEoB8T9YA_1': 2,
#  'Q2_ZTrEoB8T9YA_2': 2,
#  'Q2_ZdyiXIlKe_Y_0': 2,
#  'Q2_ZdyiXIlKe_Y_1': 2,
#  'Q2__FVzelKlBFs_0': 2,
#  'Q2__FVzelKlBFs_1': 2,
#  'Q2__FVzelKlBFs_2': 2,
#  'Q2__S991V8N-8s_1': 2,
#  'Q2__vZOEQCYSaY_1': 2,
#  'Q2_aYe-2Glruu4_2': 2,
#  'Q2_b8HVQtIoBYU_0': 2,
#  'Q2_b8HVQtIoBYU_1': 2,
#  'Q2_bfopzItCYrE_1': 2,
#  'Q2_cFWdWpyvwag_0': 2,
#  'Q2_cFWdWpyvwag_1': 2,
#  'Q2_cQp1BYDGcRo_0': 2,
#  'Q2_cQp1BYDGcRo_1': 2,
#  'Q2_cm6E860vDjY_0': 2,
#  'Q2_cm6E860vDjY_1': 2,
#  'Q2_cm6E860vDjY_2': 2,
#  'Q2_dtS02mrDMsM_0': 2,
#  'Q2_dtS02mrDMsM_1': 2,
#  'Q2_dtS02mrDMsM_2': 2,
#  'Q2_dtS02mrDMsM_3': 2,
#  'Q2_dtS02mrDMsM_4': 2,
#  'Q2_eGQUZ9FlUJ4_0': 2,
#  'Q2_eGQUZ9FlUJ4_1': 2,
#  'Q2_epX33OVpkmA_0': 2,
#  'Q2_epX33OVpkmA_1': 2,
#  'Q2_epX33OVpkmA_2': 2,
#  'Q2_ezoAduuCkUs_0': 2,
#  'Q2_f2BXXa7lPuE_0': 2,
#  'Q2_f2BXXa7lPuE_1': 2,
#  'Q2_f2BXXa7lPuE_2': 2,
#  'Q2_f2BXXa7lPuE_3': 2,
#  'Q2_fuCxYrru2S4_1': 2,
#  'Q2_fuCxYrru2S4_2': 2,
#  'Q2_gvWDOIiocuE_1': 2,
#  'Q2_ijfxkQPAQdE_1': 2,
#  'Q2_ijfxkQPAQdE_2': 2,
#  'Q2_ivCNV47tsRw_0': 2,
#  'Q2_ivCNV47tsRw_1': 2,
#  'Q2_ivCNV47tsRw_2': 2,
#  'Q2_ivCNV47tsRw_3': 2,
#  'Q2_iwxwLEvqeD8_1': 2,
#  'Q2_jIKX3ShvLxo_0': 2,
#  'Q2_jIKX3ShvLxo_1': 2,
#  'Q2_jIKX3ShvLxo_2': 2,
#  'Q2_jO2zX6Ul8GM_0': 2,
#  'Q2_jO2zX6Ul8GM_1': 2,
#  'Q2_jTPXwbDtIpA_1': 2,
#  'Q2_jTPXwbDtIpA_2': 2,
#  'Q2_jrVXitpLGMk_0': 2,
#  'Q2_jrVXitpLGMk_1': 2,
#  'Q2_jrVXitpLGMk_2': 2,
#  'Q2_k-FNDbK6Qhg_0': 2,
#  'Q2_k-FNDbK6Qhg_2': 2,
#  'Q2_k4lT-sXg3iI_0': 2,
#  'Q2_k4lT-sXg3iI_1': 2,
#  'Q2_k4lT-sXg3iI_2': 2,
#  'Q2_kKFwiXKlhC8_0': 2,
#  'Q2_kKFwiXKlhC8_1': 2,
#  'Q2_l-4Kce3YxxQ_0': 2,
#  'Q2_l-4Kce3YxxQ_1': 2,
#  'Q2_l-4Kce3YxxQ_2': 2,
#  'Q2_l-4Kce3YxxQ_3': 2,
#  'Q2_l-4Kce3YxxQ_4': 2,
#  'Q2_lFznCt5kvXM_0': 2,
#  'Q2_lalnGhxT3PQ_0': 2,
#  'Q2_lalnGhxT3PQ_1': 2,
#  'Q2_miqLU2739dk_0': 2,
#  'Q2_mlHheZbblT0_0': 2,
#  'Q2_mlHheZbblT0_1': 2,
#  'Q2_nOIBJHkqrE8_1': 2,
#  'Q2_o20YCzej5_s_0': 2,
#  'Q2_pouxqiySdI8_0': 2,
#  'Q2_pouxqiySdI8_1': 2,
#  'Q2_qlbazHayULg_0': 2,
#  'Q2_qlbazHayULg_1': 2,
#  'Q2_qlbazHayULg_10': 2,
#  'Q2_qlbazHayULg_11': 2,
#  'Q2_qlbazHayULg_12': 2,
#  'Q2_qlbazHayULg_2': 2,
#  'Q2_qlbazHayULg_4': 2,
#  'Q2_qlbazHayULg_5': 2,
#  'Q2_qlbazHayULg_6': 2,
#  'Q2_qlbazHayULg_7': 2,
#  'Q2_rEz0D3VohFA_1': 2,
#  'Q2_rEz0D3VohFA_2': 2,
#  'Q2_sEQf5lcnj_o_0': 2,
#  'Q2_sEQf5lcnj_o_1': 2,
#  'Q2_sEQf5lcnj_o_2': 2,
#  'Q2_sEQf5lcnj_o_3': 2,
#  'Q2_snfsc7pEzlk_0': 2,
#  'Q2_snfsc7pEzlk_1': 2,
#  'Q2_snfsc7pEzlk_2': 2,
#  'Q2_ufRISSD28XA_0': 2,
#  'Q2_ufRISSD28XA_1': 2,
#  'Q2_wfXSdMsd4q8_5': 2,
#  'Q2_x5ibvz38jOs_0': 2,
#  'Q2_x5ibvz38jOs_1': 2,
#  'Q2_yZGBxiNPu3k_0': 2,
#  'Q2_yhIncZ_Ue4E_0': 2,
#  'Q2_yhIncZ_Ue4E_1': 2,
#  'Q2_yhIncZ_Ue4E_2': 2,
#  'Q2_yrvKReuwVlY_0': 2,
#  'Q2_yrvKReuwVlY_1': 2,
#  'Q2_yrvKReuwVlY_2': 2,
#  'Q2_yrvKReuwVlY_3': 2,
#  'Q2_z5ewpQwGDNw_0': 2,
#  'Q2_z5ewpQwGDNw_1': 2,
#  'Q2_z5ewpQwGDNw_2': 2,
#  'Q3_-vAz_HTFEXs_0': 3,
#  'Q3_-vAz_HTFEXs_1': 3,
#  'Q3_02t1bj7ZABY_0': 3,
#  'Q3_02t1bj7ZABY_1': 3,
#  'Q3_02t1bj7ZABY_2': 3,
#  'Q3_0EWWyyV7RJA_0': 3,
#  'Q3_0c2dTJTDUR4_0': 3,
#  'Q3_0lEL_XHyhuU_0': 3,
#  'Q3_0lEL_XHyhuU_1': 3,
#  'Q3_0lEL_XHyhuU_2': 3,
#  'Q3_0lEL_XHyhuU_3': 3,
#  'Q3_0vLPYiPN7qY_3': 3,
#  'Q3_0wRQRwnQiqY_0': 3,
#  'Q3_16OaOpfOPZ0_0': 3,
#  'Q3_16OaOpfOPZ0_1': 3,
#  'Q3_1Q3MoBFh6eU_0': 3,
#  'Q3_1Q3MoBFh6eU_2': 3,
#  'Q3_1cgO42sh-ZY_0': 3,
#  'Q3_1kny88W533Q_1': 3,
#  'Q3_2eIsQtm4YNs_0': 3,
#  'Q3_2eIsQtm4YNs_1': 3,
#  'Q3_2v6gJi03LlA_0': 3,
#  'Q3_2v6gJi03LlA_1': 3,
#  'Q3_3ZnxqCZ7qGg_0': 3,
#  'Q3_4Er-eFHSHA4_0': 3,
#  'Q3_4Er-eFHSHA4_1': 3,
#  'Q3_4Er-eFHSHA4_2': 3,
#  'Q3_4Er-eFHSHA4_3': 3,
#  'Q3_77z6Ep3aOmg_0': 3,
#  'Q3_77z6Ep3aOmg_1': 3,
#  'Q3_7JIdJLkJ0S4_0': 3,
#  'Q3_7JIdJLkJ0S4_1': 3,
#  'Q3_7JIdJLkJ0S4_2': 3,
#  'Q3_7JIdJLkJ0S4_3': 3,
#  'Q3_9Xg69XrVaYU_0': 3,
#  'Q3_9Xg69XrVaYU_1': 3,
#  'Q3_9Xg69XrVaYU_2': 3,
#  'Q3_AacIP9mDLw8_1': 3,
#  'Q3_Adil-zpJdEs_0': 3,
#  'Q3_BIRDDxz0E4c_0': 3,
#  'Q3_By3JCii1k3w_0': 3,
#  'Q3_By3JCii1k3w_1': 3,
#  'Q3_By3JCii1k3w_2': 3,
#  'Q3_BzqX-9TA-GY_0': 3,
#  'Q3_D3onzY4MNxE_0': 3,
#  'Q3_D3onzY4MNxE_1': 3,
#  'Q3_D8Ed5PZXfF4_0': 3,
#  'Q3_DYBBfpEx-JI_4': 3,
#  'Q3_E5qEloUO3SM_1': 3,
#  'Q3_FH28sPhm9Dc_0': 3,
#  'Q3_FH28sPhm9Dc_1': 3,
#  'Q3_FOcdHIhI0_s_0': 3,
#  'Q3_FOcdHIhI0_s_1': 3,
#  'Q3_FUAK5TBaNY8_0': 3,
#  'Q3_FUAK5TBaNY8_2': 3,
#  'Q3_FUAK5TBaNY8_3': 3,
#  'Q3_G4rL_OtfFAU_0': 3,
#  'Q3_G4rL_OtfFAU_1': 3,
#  'Q3_H6_7DjsbROQ_0': 3,
#  'Q3_H6_7DjsbROQ_1': 3,
#  'Q3_H6_7DjsbROQ_2': 3,
#  'Q3_H6_7DjsbROQ_3': 3,
#  'Q3_H6_7DjsbROQ_4': 3,
#  'Q3_IH2KrGjKXw0_0': 3,
#  'Q3_IH2KrGjKXw0_1': 3,
#  'Q3_IH2KrGjKXw0_2': 3,
#  'Q3_ISCVfmBvYoM_0': 3,
#  'Q3_Ie5koh4qvJc_0': 3,
#  'Q3_Ie5koh4qvJc_14': 3,
#  'Q3_Ie5koh4qvJc_15': 3,
#  'Q3_Ie5koh4qvJc_18': 3,
#  'Q3_Ie5koh4qvJc_19': 3,
#  'Q3_Ie5koh4qvJc_2': 3,
#  'Q3_Ie5koh4qvJc_22': 3,
#  'Q3_Ie5koh4qvJc_23': 3,
#  'Q3_Ie5koh4qvJc_24': 3,
#  'Q3_Ie5koh4qvJc_25': 3,
#  'Q3_Ie5koh4qvJc_29': 3,
#  'Q3_Ie5koh4qvJc_3': 3,
#  'Q3_Ie5koh4qvJc_5': 3,
#  'Q3_Ie5koh4qvJc_8': 3,
#  'Q3_ItGNJM6skM4_0': 3,
#  'Q3_JNzqL24ZcZ8_0': 3,
#  'Q3_JNzqL24ZcZ8_1': 3,
#  'Q3_JNzqL24ZcZ8_2': 3,
#  'Q3_JT1XJnVmABo_1': 3,
#  'Q3_K84TcgjCRt4_0': 3,
#  'Q3_K84TcgjCRt4_1': 3,
#  'Q3_K84TcgjCRt4_2': 3,
#  'Q3_MbvPxCUMSek_0': 3,
#  'Q3_MbvPxCUMSek_1': 3,
#  'Q3_MbvPxCUMSek_2': 3,
#  'Q3_NTI9ode6bRk_0': 3,
#  'Q3_NTI9ode6bRk_1': 3,
#  'Q3_OO7zYVeK814_0': 3,
#  'Q3_OO7zYVeK814_1': 3,
#  'Q3_OO7zYVeK814_2': 3,
#  'Q3_Oku8sIpTMAE_0': 3,
#  'Q3_Oku8sIpTMAE_1': 3,
#  'Q3_Oku8sIpTMAE_2': 3,
#  'Q3_Oku8sIpTMAE_3': 3,
#  'Q3_Oku8sIpTMAE_4': 3,
#  'Q3_P-We4q3goKU_0': 3,
#  'Q3_PLfFWFZflQU_0': 3,
#  'Q3_PLfFWFZflQU_1': 3,
#  'Q3_PXOWy7NiZhk_0': 3,
#  'Q3_PXOWy7NiZhk_1': 3,
#  'Q3_QJlnTN7HRwE_0': 3,
#  'Q3_QJlnTN7HRwE_1': 3,
#  'Q3_QJlnTN7HRwE_2': 3,
#  'Q3_QJlnTN7HRwE_3': 3,
#  'Q3_REq37pDAm3A_0': 3,
#  'Q3_REq37pDAm3A_1': 3,
#  'Q3_REq37pDAm3A_3': 3,
#  'Q3_REq37pDAm3A_4': 3,
#  'Q3_RL_cmmNVLfs_0': 3,
#  'Q3_RiQMuhk_SuQ_0': 3,
#  'Q3_S1T3UF1vhSk_0': 3,
#  'Q3_TYkTOwBfFB8_0': 3,
#  'Q3_TYkTOwBfFB8_1': 3,
#  'Q3_TonQX8XbvX8_0': 3,
#  'Q3_TonQX8XbvX8_1': 3,
#  'Q3_TonQX8XbvX8_2': 3,
#  'Q3_TonQX8XbvX8_3': 3,
#  'Q3_UE0y8MHqT-g_0': 3,
#  'Q3_UJcnNfeCN1c_0': 3,
#  'Q3_UuLTvhERcnk_0': 3,
#  'Q3_UuLTvhERcnk_1': 3,
#  'Q3_VrWAZLRdQO8_0': 3,
#  'Q3_VrWAZLRdQO8_1': 3,
#  'Q3_X1p8xcarVu0_0': 3,
#  'Q3_X1p8xcarVu0_1': 3,
#  'Q3_X1p8xcarVu0_2': 3,
#  'Q3_X1p8xcarVu0_3': 3,
#  'Q3_ZvD8QSO7NPw_0': 3,
#  'Q3_ZvD8QSO7NPw_1': 3,
#  'Q3_ZvD8QSO7NPw_2': 3,
#  'Q3__S991V8N-8s_0': 3,
#  'Q3__vZOEQCYSaY_0': 3,
#  'Q3__vZOEQCYSaY_2': 3,
#  'Q3_bbU31JLtlug_0': 3,
#  'Q3_bbU31JLtlug_1': 3,
#  'Q3_bfopzItCYrE_0': 3,
#  'Q3_c6CwY8Gbw0c_0': 3,
#  'Q3_c6CwY8Gbw0c_1': 3,
#  'Q3_c6CwY8Gbw0c_2': 3,
#  'Q3_c6CwY8Gbw0c_3': 3,
#  'Q3_c6CwY8Gbw0c_4': 3,
#  'Q3_cCfEDTkuMvg_0': 3,
#  'Q3_dCoUuknChhE_0': 3,
#  'Q3_egYSmNuIFGk_1': 3,
#  'Q3_egYSmNuIFGk_2': 3,
#  'Q3_epMOLn5Axw0_0': 3,
#  'Q3_f0NbGeyJYms_0': 3,
#  'Q3_fnqb8zqHqdY_0': 3,
#  'Q3_fnqb8zqHqdY_1': 3,
#  'Q3_fnqb8zqHqdY_2': 3,
#  'Q3_fuCxYrru2S4_0': 3,
#  'Q3_g-yM0Lsp4lc_0': 3,
#  'Q3_g-yM0Lsp4lc_1': 3,
#  'Q3_gvWDOIiocuE_0': 3,
#  'Q3_gvWDOIiocuE_2': 3,
#  'Q3_iRu9KQvbtVw_0': 3,
#  'Q3_ii1Jw1-7Ka4_0': 3,
#  'Q3_ii1Jw1-7Ka4_1': 3,
#  'Q3_ii1Jw1-7Ka4_2': 3,
#  'Q3_ijfxkQPAQdE_0': 3,
#  'Q3_ilCcZpD39HU_0': 3,
#  'Q3_ilCcZpD39HU_1': 3,
#  'Q3_ilCcZpD39HU_2': 3,
#  'Q3_ilCcZpD39HU_3': 3,
#  'Q3_ilCcZpD39HU_4': 3,
#  'Q3_iwxwLEvqeD8_0': 3,
#  'Q3_jTPXwbDtIpA_0': 3,
#  'Q3_kDGmND1BgmA_0': 3,
#  'Q3_kDGmND1BgmA_1': 3,
#  'Q3_kopwU6zpS4k_0': 3,
#  'Q3_ldCQ6N9G6Mk_2': 3,
#  'Q3_ldCQ6N9G6Mk_3': 3,
#  'Q3_ldCQ6N9G6Mk_4': 3,
#  'Q3_ltxNPJda7zE_2': 3,
#  'Q3_nBIls0laAAU_0': 3,
#  'Q3_nBIls0laAAU_1': 3,
#  'Q3_nBIls0laAAU_2': 3,
#  'Q3_nBao46YGZDg_0': 3,
#  'Q3_nFunbdBrukY_0': 3,
#  'Q3_p2qihp_PnLY_0': 3,
#  'Q3_p2qihp_PnLY_1': 3,
#  'Q3_pbVGv_g4n50_0': 3,
#  'Q3_qRceKZtwRWA_1': 3,
#  'Q3_qlbazHayULg_13': 3,
#  'Q3_qlbazHayULg_3': 3,
#  'Q3_qlbazHayULg_9': 3,
#  'Q3_rEz0D3VohFA_0': 3,
#  'Q3_rrD7XMtPs0Q_0': 3,
#  'Q3_tLmXAWfbGqs_0': 3,
#  'Q3_tfuul78deOs_0': 3,
#  'Q3_tfuul78deOs_1': 3,
#  'Q3_tw_lArYiHTo_0': 3,
#  'Q3_uj3Gif77SYM_0': 3,
#  'Q3_uj3Gif77SYM_1': 3,
#  'Q3_uj3Gif77SYM_2': 3,
#  'Q3_uj3Gif77SYM_3': 3,
#  'Q3_uj3Gif77SYM_4': 3,
#  'Q3_uj3Gif77SYM_5': 3,
#  'Q3_uj3Gif77SYM_6': 3,
#  'Q3_uj3Gif77SYM_7': 3,
#  'Q3_uj3Gif77SYM_8': 3,
#  'Q3_v2an-9szi8M_0': 3,
#  'Q3_vVTP0DOL_2Q_0': 3,
#  'Q3_vVTP0DOL_2Q_1': 3,
#  'Q3_vVTP0DOL_2Q_2': 3,
#  'Q3_vVTP0DOL_2Q_3': 3,
#  'Q3_veG92Oi-DlU_0': 3,
#  'Q3_veG92Oi-DlU_1': 3,
#  'Q3_veG92Oi-DlU_2': 3,
#  'Q3_wS0RzrBL9UI_0': 3,
#  'Q3_wS0RzrBL9UI_1': 3,
#  'Q3_wS0RzrBL9UI_2': 3,
#  'Q3_wfXSdMsd4q8_0': 3,
#  'Q3_wfXSdMsd4q8_1': 3,
#  'Q3_wfXSdMsd4q8_2': 3,
#  'Q3_wfXSdMsd4q8_3': 3,
#  'Q3_wfXSdMsd4q8_4': 3,
#  'Q3_wlOa1jkTn_U_0': 3,
#  'Q3_wlOa1jkTn_U_1': 3,
#  'Q3_wlOa1jkTn_U_2': 3,
#  'Q3_wqc8iqbDsGM_0': 3,
#  'Q3_wqc8iqbDsGM_1': 3,
#  'Q3_wqc8iqbDsGM_2': 3,
#  'Q3_wqc8iqbDsGM_3': 3,
#  'Q3_wqc8iqbDsGM_4': 3,
#  'Q3_wxXpvnmq_-E_0': 3,
#  'Q3_wxXpvnmq_-E_1': 3,
#  'Q3_wxXpvnmq_-E_2': 3,
#  'Q3_x4B0raxVODA_0': 3,
#  'Q3_x4B0raxVODA_1': 3,
#  'Q3_x4B0raxVODA_2': 3,
#  'Q3_x4B0raxVODA_3': 3,
#  'Q3_xIsvaT20pZ0_0': 3,
#  'Q3_xIsvaT20pZ0_1': 3,
#  'Q3_xYZ8n8ULaNo_0': 3,
#  'Q3_xYZ8n8ULaNo_1': 3,
#  'Q3_yZGBxiNPu3k_1': 3,
#  'Q3_yZGBxiNPu3k_2': 3,
#  'Q3_zMa78n8ULtE_0': 3,
#  'Q3_zMa78n8ULtE_1': 3,
#  'Q3_zjr_-ql5Avk_0': 3,
#  'Q3_zjr_-ql5Avk_1': 3,
#  'Q3_zjr_-ql5Avk_2': 3,
#  'Q3_zvWX_dwQPtU_0': 3,
#  'Q3_zvWX_dwQPtU_1': 3,
#  'Q3_zvWX_dwQPtU_2': 3,
#  'Q4_--2B4d4lQhs_3': 4,
#  'Q4_-_FjI4bT2Wo_0': 4,
#  'Q4_-_FjI4bT2Wo_1': 4,
#  'Q4_-_FjI4bT2Wo_2': 4,
#  'Q4_0c2dTJTDUR4_1': 4,
#  'Q4_12tDlCQVRtA_0': 4,
#  'Q4_12tDlCQVRtA_1': 4,
#  'Q4_12tDlCQVRtA_2': 4,
#  'Q4_170KC2CbJ7Y_0': 4,
#  'Q4_170KC2CbJ7Y_1': 4,
#  'Q4_1A9Hh2GrDTs_0': 4,
#  'Q4_1Qc15G0ZHIg_0': 4,
#  'Q4_1fdxsFbnsX4_0': 4,
#  'Q4_1fdxsFbnsX4_1': 4,
#  'Q4_1vjy9oMFa8c_0': 4,
#  'Q4_1vjy9oMFa8c_1': 4,
#  'Q4_1vjy9oMFa8c_3': 4,
#  'Q4_22S3w4idugs_0': 4,
#  'Q4_2Z9SjI131jA_5': 4,
#  'Q4_2Z9SjI131jA_6': 4,
#  'Q4_2w5XkAt_3WU_0': 4,
#  'Q4_3As1t6JySDE_0': 4,
#  'Q4_3N2G21U7guk_0': 4,
#  'Q4_3N2G21U7guk_1': 4,
#  'Q4_3N2G21U7guk_2': 4,
#  'Q4_3N2G21U7guk_4': 4,
#  'Q4_3TYeU9idRGI_0': 4,
#  'Q4_3TYeU9idRGI_1': 4,
#  'Q4_5DqIntcmdRI_0': 4,
#  'Q4_5DqIntcmdRI_1': 4,
#  'Q4_5J_zI7QE9W8_0': 4,
#  'Q4_5J_zI7QE9W8_1': 4,
#  'Q4_5J_zI7QE9W8_2': 4,
#  'Q4_5Ju9q1N2x0E_0': 4,
#  'Q4_5Ju9q1N2x0E_1': 4,
#  'Q4_61EA0xRX8gE_2': 4,
#  'Q4_6kRPHamGDSo_2': 4,
#  'Q4_6oLmO9ZSJt0_0': 4,
#  'Q4_6oLmO9ZSJt0_1': 4,
#  'Q4_7gifuoofgpk_0': 4,
#  'Q4_7gifuoofgpk_1': 4,
#  'Q4_7yW9c7t8Hq0_0': 4,
#  'Q4_8TYY0qG-KOw_0': 4,
#  'Q4_9eMxCs-LXCE_0': 4,
#  'Q4_9eMxCs-LXCE_1': 4,
#  'Q4_9eMxCs-LXCE_2': 4,
#  'Q4_9v2WSpn4FCw_9': 4,
#  'Q4_ADJ_PDauy-g_0': 4,
#  'Q4_ADJ_PDauy-g_1': 4,
#  'Q4_ADJ_PDauy-g_2': 4,
#  'Q4_AjN_5CdVUdw_0': 4,
#  'Q4_B3aRl8iTEKw_0': 4,
#  'Q4_B3aRl8iTEKw_1': 4,
#  'Q4_BIRDDxz0E4c_1': 4,
#  'Q4_BaHHHgDd0BU_0': 4,
#  'Q4_BaHHHgDd0BU_1': 4,
#  'Q4_Cir1kZyB7QM_0': 4,
#  'Q4_Cir1kZyB7QM_1': 4,
#  'Q4_CkjAksZstEA_0': 4,
#  'Q4_CkjAksZstEA_1': 4,
#  'Q4_DX1IK3z1w10_0': 4,
#  'Q4_DvIH5yUrboc_0': 4,
#  'Q4_DvIH5yUrboc_1': 4,
#  'Q4_DvIH5yUrboc_2': 4,
#  'Q4_Dw7M69CidJ8_0': 4,
#  'Q4_Dw7M69CidJ8_1': 4,
#  'Q4_Dw7M69CidJ8_2': 4,
#  'Q4_Dw7M69CidJ8_3': 4,
#  'Q4_E5qEloUO3SM_0': 4,
#  'Q4_E6MARl3zjnQ_0': 4,
#  'Q4_FSzOgraSKhs_0': 4,
#  'Q4_FSzOgraSKhs_1': 4,
#  'Q4_FoTXpYZXxJs_0': 4,
#  'Q4_FoTXpYZXxJs_1': 4,
#  'Q4_FyK_c-TIcCA_0': 4,
#  'Q4_FyK_c-TIcCA_1': 4,
#  'Q4_FyK_c-TIcCA_2': 4,
#  'Q4_GAvPwG2wYZM_0': 4,
#  'Q4_GAvPwG2wYZM_1': 4,
#  'Q4_GbUV3TXUzeQ_0': 4,
#  'Q4_Gcbk0GPT3-g_0': 4,
#  'Q4_Gcbk0GPT3-g_1': 4,
#  'Q4_HQ8ISDX6PiI_0': 4,
#  'Q4_HQ8ISDX6PiI_1': 4,
#  'Q4_HYVmgq5Y93g_0': 4,
#  'Q4_HYVmgq5Y93g_1': 4,
#  'Q4_HYVmgq5Y93g_2': 4,
#  'Q4_Hwd6l9jK7bo_0': 4,
#  'Q4_Hwd6l9jK7bo_1': 4,
#  'Q4_I2MrA-o5H8I_0': 4,
#  'Q4_I2MrA-o5H8I_1': 4,
#  'Q4_I2MrA-o5H8I_2': 4,
#  'Q4_Ie5koh4qvJc_1': 4,
#  'Q4_Ie5koh4qvJc_16': 4,
#  'Q4_Ie5koh4qvJc_17': 4,
#  'Q4_Ie5koh4qvJc_20': 4,
#  'Q4_Ie5koh4qvJc_21': 4,
#  'Q4_Ie5koh4qvJc_27': 4,
#  'Q4_Ie5koh4qvJc_28': 4,
#  'Q4_Ie5koh4qvJc_31': 4,
#  'Q4_Ie5koh4qvJc_32': 4,
#  'Q4_Ie5koh4qvJc_4': 4,
#  'Q4_IgpNyJVWcBo_0': 4,
#  'Q4_J6X3rVU1H-c_0': 4,
#  'Q4_JP3QKZlyQz4_0': 4,
#  'Q4_JP3QKZlyQz4_1': 4,
#  'Q4_JP3QKZlyQz4_2': 4,
#  'Q4_JT1XJnVmABo_0': 4,
#  'Q4_JT1XJnVmABo_1': 4,
#  'Q4_JT1XJnVmABo_2': 4,
#  'Q4_JxSU49jFKwM_0': 4,
#  'Q4_JxSU49jFKwM_1': 4,
#  'Q4_KRlAez34QfE_0': 4,
#  'Q4_KRlAez34QfE_1': 4,
#  'Q4_KRlAez34QfE_2': 4,
#  'Q4_KxlqB3j0zys_2': 4,
#  'Q4_KxlqB3j0zys_3': 4,
#  'Q4_KxlqB3j0zys_4': 4,
#  'Q4_MT2_mXn-vGU_0': 4,
#  'Q4_MT2_mXn-vGU_1': 4,
#  'Q4_MT2_mXn-vGU_2': 4,
#  'Q4_NP0lwB-_-og_0': 4,
#  'Q4_NzJjMGJg1wE_0': 4,
#  'Q4_OUb9uaOlWAM_0': 4,
#  'Q4_OgkB7PfqWzA_0': 4,
#  'Q4_OgkB7PfqWzA_1': 4,
#  'Q4_OoxI6k0Qsno_0': 4,
#  'Q4_OoxI6k0Qsno_1': 4,
#  'Q4_OyaY4213c2A_0': 4,
#  'Q4_OyaY4213c2A_1': 4,
#  'Q4_PK8YIUaV3Xw_0': 4,
#  'Q4_PK8YIUaV3Xw_1': 4,
#  'Q4_PZN7XLKzLDI_1': 4,
#  'Q4_Q49PWE0RJLY_0': 4,
#  'Q4_Q49PWE0RJLY_1': 4,
#  'Q4_QBJ6YYYpIyk_0': 4,
#  'Q4_T92R7xjce34_0': 4,
#  'Q4_TOXg4-ZGb-g_0': 4,
#  'Q4_TOXg4-ZGb-g_1': 4,
#  'Q4_TOXg4-ZGb-g_2': 4,
#  'Q4_Tc684nD8CEA_0': 4,
#  'Q4_Tc684nD8CEA_1': 4,
#  'Q4_Tc684nD8CEA_2': 4,
#  'Q4_Tc684nD8CEA_3': 4,
#  'Q4_Tc684nD8CEA_4': 4,
#  'Q4_TcFVq0leii4_0': 4,
#  'Q4_Tjno89OVuRI_0': 4,
#  'Q4_Tjno89OVuRI_1': 4,
#  'Q4_UaYYMRkHMYc_0': 4,
#  'Q4_UaYYMRkHMYc_1': 4,
#  'Q4_UaYYMRkHMYc_2': 4,
#  'Q4_UbKAl4roB8k_0': 4,
#  'Q4_UbKAl4roB8k_1': 4,
#  'Q4_UbKAl4roB8k_2': 4,
#  'Q4_UpHutdJvZMI_0': 4,
#  'Q4_UpHutdJvZMI_1': 4,
#  'Q4_UpHutdJvZMI_2': 4,
#  'Q4_Ury1cdB79s0_0': 4,
#  'Q4_Ury1cdB79s0_1': 4,
#  'Q4_V3Y9L4UOcpk_0': 4,
#  'Q4_V3Y9L4UOcpk_1': 4,
#  'Q4_VCSDjQxAJzc_0': 4,
#  'Q4_VCSDjQxAJzc_1': 4,
#  'Q4_VCSDjQxAJzc_2': 4,
#  'Q4_VXh4IaR5C6s_0': 4,
#  'Q4_V_jbWvQNh5c_0': 4,
#  'Q4_V_jbWvQNh5c_1': 4,
#  'Q4_XC_SiJszQx0_0': 4,
#  'Q4_XC_SiJszQx0_2': 4,
#  'Q4_XPLYvpyfKUM_0': 4,
#  'Q4_XPLYvpyfKUM_1': 4,
#  'Q4_XWk5XUEBXmg_0': 4,
#  'Q4_XWk5XUEBXmg_1': 4,
#  'Q4_Xf2fox7zhCQ_0': 4,
#  'Q4_Xf2fox7zhCQ_1': 4,
#  'Q4_Xf2fox7zhCQ_2': 4,
#  'Q4_Xlv4PPGrRRs_0': 4,
#  'Q4_Xlv4PPGrRRs_1': 4,
#  'Q4_Y1F0c3zgMJo_0': 4,
#  'Q4_Y1F0c3zgMJo_1': 4,
#  'Q4_YAAxPW1GB7w_0': 4,
#  'Q4_YAAxPW1GB7w_1': 4,
#  'Q4_YhXRyOl5pi0_0': 4,
#  'Q4__BK2o77sTc0_2': 4,
#  'Q4_a5QCcwEjxAk_0': 4,
#  'Q4_a5QCcwEjxAk_1': 4,
#  'Q4_aQ4PIaRMLwE_0': 4,
#  'Q4_aQ4PIaRMLwE_1': 4,
#  'Q4_aQ4PIaRMLwE_2': 4,
#  'Q4_bfopzItCYrE_2': 4,
#  'Q4_biROWEwkDQQ_0': 4,
#  'Q4_biROWEwkDQQ_1': 4,
#  'Q4_biROWEwkDQQ_2': 4,
#  'Q4_cXxGBDgFCs8_0': 4,
#  'Q4_cXxGBDgFCs8_1': 4,
#  'Q4_cXxGBDgFCs8_2': 4,
#  'Q4_d_49EtXDMFE_0': 4,
#  'Q4_d_49EtXDMFE_1': 4,
#  'Q4_d_49EtXDMFE_2': 4,
#  'Q4_e838BE_MH6s_0': 4,
#  'Q4_egYSmNuIFGk_0': 4,
#  'Q4_f2b4kpdw7_c_0': 4,
#  'Q4_f2b4kpdw7_c_1': 4,
#  'Q4_fOYX0uH8mSQ_0': 4,
#  'Q4_fShAWhXIits_0': 4,
#  'Q4_fShAWhXIits_1': 4,
#  'Q4_g15aRCHUJEI_0': 4,
#  'Q4_g15aRCHUJEI_1': 4,
#  'Q4_g15aRCHUJEI_2': 4,
#  'Q4_gwmVjvR-sVs_2': 4,
#  'Q4_gxsdWKc1QaM_0': 4,
#  'Q4_heBmBQDWj-M_0': 4,
#  'Q4_heBmBQDWj-M_1': 4,
#  'Q4_heBmBQDWj-M_2': 4,
#  'Q4_hoPp_GLXQis_0': 4,
#  'Q4_hoPp_GLXQis_1': 4,
#  'Q4_iGHgeUCPotc_0': 4,
#  'Q4_iHPKusssXzk_0': 4,
#  'Q4_iHPKusssXzk_1': 4,
#  'Q4_iHPKusssXzk_2': 4,
#  'Q4_iXiSFSGws-c_0': 4,
#  'Q4_iXiSFSGws-c_1': 4,
#  'Q4_iXiSFSGws-c_2': 4,
#  'Q4_j8Ir-ssM-AA_0': 4,
#  'Q4_j8Ir-ssM-AA_1': 4,
#  'Q4_jCLgDtk695I_0': 4,
#  'Q4_jCLgDtk695I_1': 4,
#  'Q4_jCLgDtk695I_2': 4,
#  'Q4_jCLgDtk695I_3': 4,
#  'Q4_jCLgDtk695I_4': 4,
#  'Q4_jNzZCplNNyY_0': 4,
#  'Q4_jNzZCplNNyY_1': 4,
#  ...}

# %%
class TransformerDataset(torch.utils.data.Dataset):
    
    def __init__(self, dataset, seq_len, cond=False):
      """
        Args:
            dataset: token dataset
            ttps: tokens per second
            seconds: seconds per example
      """
      
      self.ids = []
      self.dataset = []
      self.conditions = []
      
      self.cond = cond
      for i, data in enumerate(dataset['sequences']):
      
        for j in range(0, len(data)-(seq_len+1), seq_len+1):
          #if dataset['conditions'][i][0] == 18.:
          self.ids.append(dataset['ids'][i])
                    
          # we will use seq[:-1] as input and seq[1:] as target
          self.dataset.append(data[j: j+seq_len+1])

          if cond:
            self.conditions.append(dataset['conditions'][i])
          
      if type(self.ids[0] == str):
        self.ids = torch.arange(len(self.ids)).unsqueeze(-1)
      else:
        self.ids = torch.Tensor(self.ids)#[:4]

      self.dataset = torch.Tensor(self.dataset)#[:4]
      if cond:
        self.conditions = torch.Tensor(self.conditions)#[:4]  

    def __len__(self):
      return len(self.dataset)

    def __getitem__(self, idx):
      input = self.dataset[idx][:-1].long()
      target = self.dataset[idx][1:].long()

      if self.cond:
        batch = {'ids': self.ids[idx], 'inputs': input, 'targets': target, 'conditions': self.conditions[idx].long()}
      else:
        batch = {'ids': self.ids[idx], 'inputs': input, 'targets': target, 'conditions': torch.Tensor([float('nan')])}
      return batch

# %%
import itertools
import os
import glob
import time
from collections import Counter
from re import S
import itertools
import pickle as pkl
from note_seq.chord_symbols_lib import ChordSymbolError
from note_seq.musicxml_parser import ChordSymbol
import numpy as np
import note_seq
from collections import defaultdict

# %%
class MidiEncoder():
    def __init__(self, steps_per_sec, num_vel_bins, min_pitch, max_pitch, stretch_factors=[1.0], pitch_transpose_range=[0]):
        self.steps_per_sec = steps_per_sec
        self.num_vel_bins = num_vel_bins
        self.min_pitch = min_pitch
        self.max_pitch = max_pitch

        self.events_to_ids = self.make_vocab()
        self.ids_to_events = {value: key for key, value in self.events_to_ids.items()}
        self.vocab_size = len(self.events_to_ids)
        
        self.strech_factors = stretch_factors
        self.transpose_amounts = list(range(pitch_transpose_range[0],
                                     pitch_transpose_range[-1]+1))
        
        self.augment_params = [(s, t) for s in self.strech_factors for t in self.transpose_amounts]

        self.encoded_sequences = {'ids':[], 'sequences': []}
                
    def make_vocab(self):
        vocab = defaultdict(list)
        items = 0
        for note in range(self.min_pitch, self.max_pitch + 1):
            vocab[f"NOTE_ON_{note}"] = items
            items+=1
        for note in range(self.min_pitch, self.max_pitch + 1):
            vocab[f"NOTE_OFF_{note}"] = items
            items+=1
        for shift in range(1, self.steps_per_sec+1):
            vocab[f"TIME_SHIFT_{shift}"] = items
            items+=1
        for vel in range(1, self.num_vel_bins+1):
            vocab[f"VELOCITY_{vel}"] = items
            items+=1
        return dict(vocab)

    def filter_pitches(self, note_sequence):
        note_list = []
        deleted_note_count = 0
        end_time = 0
        for note in note_sequence.notes:
            if self.min_pitch <= note.pitch <= self.max_pitch:
                end_time = max(end_time, note.end_time)
                note_list.append(note)
            else:
                deleted_note_count += 1
        
        if deleted_note_count >= 0:
            del note_sequence.notes[:]
            note_sequence.notes.extend(note_list)
        note_sequence.total_time = end_time
        
    def encode_midi_file(self, midi_file, strech_factor=1, transpose_amount=0):
        note_sequence = note_seq.midi_file_to_note_sequence(midi_file)
        
        note_sequence = note_seq.apply_sustain_control_changes(note_sequence)
        del note_sequence.control_changes[:]

        self.filter_pitches(note_sequence)

        if strech_factor != 1 or transpose_amount != 0:
            note_sequence = self.augment(note_sequence, strech_factor, transpose_amount)
        encoded_performance = self.encode_note_sequence(note_sequence)
        
        return encoded_performance
    
    def encode_note_sequence(self, note_sequence):
        quantized_seq = note_seq.quantize_note_sequence_absolute(note_sequence, self.steps_per_sec)
                
        performance = note_seq.Performance(quantized_seq, num_velocity_bins=self.num_vel_bins)
        
        encoded_performance = self.encode_performance(performance)

        return encoded_performance

    def encode_performance(self, performance):
        encoded_performance = []
        for event in performance:
            event_name=None
            if event.event_type == note_seq.PerformanceEvent.NOTE_ON:
                event_name = f"NOTE_ON_{event.event_value}"
            if event.event_type == note_seq.PerformanceEvent.NOTE_OFF:
                event_name = f"NOTE_OFF_{event.event_value}"
            if event.event_type == note_seq.PerformanceEvent.TIME_SHIFT:
                event_name = f"TIME_SHIFT_{event.event_value}"
            if event.event_type == note_seq.PerformanceEvent.VELOCITY:
                event_name = f"VELOCITY_{event.event_value}"
            
            if event_name:
                encoded_performance.append(self.events_to_ids[event_name])
            else: 
                raise ValueError(f"Unknown event type: {event.event_type} at position {len(performance)}")
        
        return encoded_performance
    
    def decode_to_performance(self, encoded_performance):
        decoded_performance = note_seq.Performance(quantized_sequence=None,
        steps_per_second=self.steps_per_sec, num_velocity_bins=self.num_vel_bins)
        
        #INCUDE?
        '''
        tokens = []
        
        for i, event_id in enumerate(encoded_performance):
            if len(tokens) >= 2 and self.ids_to_events[tokens[-1]] == 'TIME_SHIFT_100' and self.ids_to_events[event_id] == 'TIME_SHIFT_100':
                continue
            tokens.append(event_id)
        '''

        for id in encoded_performance:
            try:
                event_name = self.ids_to_events[id]
                event_splits = event_name.split('_')
                event_type, event_value = '_'.join(event_splits[:-1]), int(event_splits[-1])
                if event_type == 'NOTE_ON':
                    event = note_seq.PerformanceEvent(
                            event_type = note_seq.PerformanceEvent.NOTE_ON, event_value=event_value)
                if event_type == 'NOTE_OFF':
                    event = note_seq.PerformanceEvent(
                            event_type = note_seq.PerformanceEvent.NOTE_OFF, event_value=event_value)
                if event_type == 'TIME_SHIFT':
                    event = note_seq.PerformanceEvent(
                            event_type = note_seq.PerformanceEvent.TIME_SHIFT, event_value=event_value)
                if event_type == 'VELOCITY':
                    event = note_seq.PerformanceEvent(
                            event_type = note_seq.PerformanceEvent.VELOCITY, event_value=event_value)
                    
                decoded_performance.append(event)
            except:
                raise ValueError("Unknown event index: %s" % id)
        return decoded_performance

    def decode_to_note_sequence(self, encoded_performance):
        decoded_performance = self.decode_to_performance(encoded_performance)
        note_sequence = decoded_performance.to_sequence(max_note_duration=3)
        return note_sequence

    def decode_to_midi_file(self, encoded_performance, save_path):
        note_sequence = self.decode_to_note_sequence(encoded_performance)
        note_seq.note_sequence_to_midi_file(note_sequence, save_path)

    def augment(self, note_sequence, stretch_factor, transpose_amount):
        augmented_note_sequence = note_seq.sequences_lib.stretch_note_sequence(note_sequence,
                                    stretch_factor, in_place=False)
        
        try: 
            _, num_deleted_notes = note_seq.sequences_lib.transpose_note_sequence(
                    augmented_note_sequence, transpose_amount,
                    min_allowed_pitch = self.min_pitch, max_allowed_pitch=self.max_pitch,
                    in_place=True
            )
        except ChordSymbolError:
            print('Transposition of chord symbol(s) failed.')
        if num_deleted_notes:
            print('Transposition caused out-of-range pitch(es)')
        return augmented_note_sequence 

    def encode_midi_list(self, midi_list, pkl_path=None):
        for midi_file in midi_list:
            print(midi_file)
            root, ext = os.path.splitext(os.path.basename(midi_file))
            for sf, ta in self.augment_params:
                self.encoded_sequences['ids'].append(root + '_' + str(sf) + '_' + str(ta) + ext)
                time0 = time.time()
                
                encoded_sequence = self.encode_midi_file(midi_file, sf, ta)
                
                print(time.time()-time0)
                self.encoded_sequences['sequences'].append(encoded_sequence)
        
        if pkl_path != None:
            with open(pkl_path, 'wb') as handle:
                pkl.dump(self.encoded_sequences, handle, protocol=pkl.HIGHEST_PROTOCOL)
        return self.encoded_sequences   

    def calculate_scores(self, midi_file, which_scores='all'):
        if type(midi_file) == str:
            midi_file = [midi_file]
        if which_scores == 'all':
            func_list = [pitch_count, note_count, note_range, average_inter_onset_interval, average_pitch_interval]
        else:
            func_list  = {func.__name__: [] for func in which_scores}
             
            
        scores = {func.__name__: [] for func in func_list}
        for filename in midi_file:
                for func in func_list:
                    scores[func.__name__].append(func(filename, self.min_pitch, self.max_pitch) if func.__name__ != 'average_inter_onset_interval' else \
                                            average_inter_onset_interval(self.min_pitch, self.max_pitch, self.steps_per_sec))
    
        return scores

# %% [markdown]
# ### data representation

# %%
# # Map notes to integers
# note_to_int = {note['pitch']: idx for idx, note in enumerate(notes)}
# int_to_note = {idx: note for note, idx in note_to_int.items()}

# # Convert notes to integers
# notes_as_int = [note_to_int[note['pitch']] for note in notes]

# # Define sequence length and create input-output pairs
# sequence_length = 100  # Define the length of input sequences
# input_sequences = []
# output_sequences = []

# for i in range(0, len(notes_as_int) - sequence_length, 1):
#     input_seq = notes_as_int[i:i + sequence_length]
#     output_seq = notes_as_int[i + sequence_length]
#     input_sequences.append(input_seq)
#     output_sequences.append(output_seq)

# # Convert to PyTorch tensors
# input_sequences = torch.LongTensor(input_sequences)
# output_sequences = torch.LongTensor(output_sequences)

# %%
# input_sequences.shape, output_sequences.shape
# Out:
# (torch.Size([1154, 100]), torch.Size([1154]))

# %% [markdown]
# ### transformer model

# %%
import torch
import torch.nn as nn

class MusicTransformer(nn.Module):
    def __init__(self, vocab_size, d_model=256, num_layers=6, num_heads=8, d_feedforward=512, dropout=0.1):
        super(MusicTransformer, self).__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)
        
        # Transformer layers
        self.encoder_layers = nn.ModuleList([
            nn.TransformerEncoderLayer(d_model, num_heads, d_feedforward, dropout) 
            for _ in range(num_layers)
        ])
        self.transformer_encoder = nn.TransformerEncoder(self.encoder_layers, num_layers)
        
        self.decoder = nn.Linear(d_model, vocab_size)

    def forward(self, x):
        x = self.embedding(x)
        x = x.permute(1, 0, 2)  # Change dimensions for transformer
        
        output = self.transformer_encoder(x)
        output = self.decoder(output[-1])  # Only use the output of the last time step
        
        return output

# %%
vocab_size = len(note_to_int)  # Adjust based on your vocabulary size
model = MusicTransformer(vocab_size)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
dataset = "midis/"

# %%
from torch.utils.data import DataLoader, TensorDataset

# Convert input and output sequences to PyTorch Dataset
dataset = TensorDataset(input_sequences, output_sequences)

# Create a DataLoader
batch_size = 32  # Define your batch size
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
num_epochs = 10  # Define the number of epochs
for epoch in range(num_epochs):
    total_loss = 0
    
    for i, (inputs, targets) in enumerate(dataloader):
        optimizer.zero_grad()
        output = model(inputs)
        
        # Reshape targets to match the expected shape [batch_size]
        targets = targets.view(-1)  
        
        # Calculate the loss
        loss = criterion(output, targets)
        total_loss += loss.item()
        
        loss.backward()
        optimizer.step()

    # Calculate average loss per epoch
    average_loss = total_loss / len(dataloader)
    print(f"Epoch [{epoch+1}/{num_epochs}], Average Loss: {average_loss}")
